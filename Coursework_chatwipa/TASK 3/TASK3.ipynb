# %% [markdown]
# # **TASK 3: Language Model:**

# %% [markdown]
# **Project Setup Guide**
#
# 1. Unzipping and Uploading the Project
#
#   - Unzip the `Coursework_chatwipa.zip` file.
#   - Upload the extracted folder to your Google Drive, maintaining the following structure:
#
# ```
# drive
# |- Coursework_chatwipa
# |  |- TASK 1
# |  |- TASK 2
# |  |- TASK 3
# |  |  |- Model
# |  |  |  |- task3_gru_nopunc_model.keras
# |  |  |  |- task3_lstm_nopunc_model.keras
# |  |  |  |- task3_gru_withpunc_model.keras
# |  |  |  |- tokenizer_no_punctuation.pkl
# |  |  |  |- tokenizer_with_punctuation.pkl
# |  |  |- TASK3.ipynb
# |  |
# ```
#
# 2. Uploading Additional Data
#
#     - Place the dataset text files (`61262-0.txt`) into the `TASK 3` folder.
#     - The final folder structure should be:
#
# ```
# drive
# |- Coursework_chatwipa
# |  |- TASK 1
# |  |- TASK 2
# |  |- TASK 3
# |  |  |- Model
# |  |  |  |- task3_gru_nopunc_model.keras
# |  |  |  |- task3_lstm_nopunc_model.keras
# |  |  |  |- task3_gru_withpunc_model.keras
# |  |  |  |- tokenizer_no_punctuation.pkl
# |  |  |  |- tokenizer_with_punctuation.pkl
# |  |  |- TASK3.ipynb
# |  |  |- 61262-0.txt
# |  |
# ```
#
# 3. Running the Demonstration
#
#   - Navigate to the **Demonstration** section of the notebook to test the process before proceeding further.

# %% [markdown]
# Install library

# %%
# !pip install -q -U keras-tuner
# !pip install rouge-score
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.3 MB/s eta 0:00:00
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (4.67.1)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=e1b007f0eac9eb10873acf7cf40038875386cc04edd2fdc7ffbe62c8f8384b94
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, GRU, LayerNormalization, BatchNormalization
import keras_tuner as kt
import re
from keras.optimizers import Adam, RMSprop, SGD
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import pickle
import spacy
from rouge_score import rouge_scorer

# %% [markdown]
# ## 1. Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Load and preprocess the text
with open("/content/drive/MyDrive/Coursework_chatwipa/TASK 3/61262-0.txt", 'r', encoding='utf-8') as file:
    text = file.read().lower()

# %%
text
# Out:
# "*** start of the project gutenberg ebook 61262 ***\n\n  poirot investigates\n\n\n\n\n  by the same author\n\n  the mysterious affair at styles\n\n  the secret adversary\n\n  the murder on the links\n\n  the bodley head\n\n\n\n\n  poirot investigates\n\n  by agatha christie\n\n\n\n\n  london\n\n  john lane the bodley head limited\n\n\n\n\n  first published in great britain by\n  john lane company, the bodley head limited, 1924\n\n  copyright © 1924 agatha christie limited\n\n\n\n\n  contents\n\n\n  i the adventure of “the western star”\n\n  ii the tragedy at marsdon manor\n\n  iii the adventure of the cheap flat\n\n  iv the mystery of hunter’s lodge\n\n  v the million dollar bond robbery\n\n  vi the adventure of the egyptian tomb\n\n  vii jewel robbery at the _grand metropolitan_\n\n  viii the kidnapped prime minister\n\n  ix the disappearance of mr. davenheim\n\n  x the adventure of the italian nobleman\n\n  xi the case of the missing will\n\n\n\n\n  poirot investigates\n\n\n\n\n  poirot investigates\n\n\n  i\n\n\n  the adventure of “the western star”\n\ni was standing at the window of poirot’s rooms looking out idly on\nthe street below.\n\n“that’s queer,” i ejaculated suddenly beneath my breath.\n\n“what is, _mon ami_?” asked poirot placidly, from the depths of\nhis comfortable chair.\n\n“deduce, poirot, from the following facts! here is a young lady,\nrichly dressed—fashionable hat, magnificent furs. she is coming\nalong slowly, looking up at the houses as she goes. unknown to her,\nshe is being shadowed by three men and a middle-aged woman. they\nhave just been joined by an errand boy who points after the girl,\ngesticulating as he does so. what drama is this being played? is\nthe girl a crook, and are the shadowers detectives preparing to\narrest her? or are _they_ the scoundrels, and are they plotting to\nattack an innocent victim? what does the great detective say?”\n\n“the great detective, _mon ami_, chooses, as ever, the simplest\ncourse. he rises to see for himself.” and my friend joined me at\nthe window.\n\nin a minute he gave vent to an amused chuckle.\n\n“as usual, your facts are tinged with your incurable romanticism.\nthat is miss mary marvell, the film star. she is being followed by\na bevy of admirers who have recognized her. and, _en passant_, my\ndear hastings, she is quite aware of the fact!”\n\ni laughed.\n\n“so all is explained! but you get no marks for that, poirot. it\nwas a mere matter of recognition.”\n\n“_en vérité!_ and how many times have you seen mary marvell on the\nscreen, _mon cher_?”\n\ni thought.\n\n“about a dozen times perhaps.”\n\n“and i—once! yet _i_ recognize her, and _you_ do not.”\n\n“she looks so different,” i replied rather feebly.\n\n“ah! _sacré_!” cried poirot. “is it that you expect her to promenade\nherself in the streets of london in a cowboy hat, or with bare\nfeet, and a bunch of curls, as an irish colleen? always with you\nit is the non-essentials! remember the case of the dancer, valerie\nsaintclair.”\n\ni shrugged my shoulders, slightly annoyed.\n\n“but console yourself, _mon ami_,” said poirot, calming down. “all\ncannot be as hercule poirot! i know it well.”\n\n“you really have the best opinion of yourself of anyone i ever\nknew!” i cried, divided between amusement and annoyance.\n\n“what will you? when one is unique, one knows it! and others share\nthat opinion—even, if i mistake not, miss mary marvell.”\n\n“what?”\n\n“without doubt. she is coming here.”\n\n“how do you make that out?”\n\n“very simply. this street, it is not aristocratic, _mon ami_! in\nit there is no fashionable doctor, no fashionable dentist—still\nless is there a fashionable milliner! but there _is_ a fashionable\ndetective. _oui_, my friend, it is true—i am become the mode, the\n_dernier cri_! one says to another: ‘_comment?_ you have lost your\ngold pencil-case? you must go to the little belgian. he is too\nmarvellous! every one goes! _courez!’_ and they arrive! in flocks,\n_mon ami_! with problems  ...

# %% [markdown]
# ## 2. Pre-processing

# %% [markdown]
# ### 2.1 Clean text

# %% [markdown]
# #### 2.1.1 Clean all punctuation

# %%
# Remove Gutenberg header and footer (if present)
text_no_punctuation = re.sub(r"\*\*\* START OF THE PROJECT GUTENBERG EBOOK.*?\*\*\*", "", text, flags=re.DOTALL)
text_no_punctuation = re.sub(r"\*\*\* END OF THE PROJECT GUTENBERG EBOOK.*?\*\*\*", "", text_no_punctuation, flags=re.DOTALL)

# Remove excessive newlines
text_no_punctuation = re.sub(r"\n{2,}", " ", text_no_punctuation).strip()
# Remove non-alphabet characters:
text_no_punctuation = re.sub(r'[^a-zA-Z\s]', '', text_no_punctuation)
# Remove HTML tags:
text_no_punctuation = re.sub(r'<.*?>', '', text_no_punctuation)
# Remove space:
text_no_punctuation = re.sub(r'\n', ' ', text_no_punctuation)

# %%
text_no_punctuation
# Out:
*\*\* END OF THE PROJECT GUTENBERG EBOOK.*?\*\*\*", "", text_with_punctuation, flags=re.DOTALL)

# Remove excessive newlines and multiple space
text_with_punctuation = re.sub(r"\n{2,}", " ", text_with_punctuation).strip()
text_with_punctuation = re.sub(r"\s{2,}", " ", text_with_punctuation)
text_with_punctuation = re.sub(r'\s+', ' ', text_with_punctuation)
# Remove non-alphabet characters except full stop and question mark
text_with_punctuation = re.sub(r"[^a-zA-Z\s.?\']", "", text_with_punctuation)
# Remove HTML tags
text_with_punctuation = re.sub(r"<.*?>", "", text_with_punctuation)
# Add spaces around punctuation to separate them
text_with_punctuation = re.sub(r"([.?])", r" \1", text_with_punctuation)

# %%
text_with_punctuation
# Out:
# " start of the project gutenberg ebook   poirot investigates by the same author the mysterious affair at styles the secret adversary the murder on the links the bodley head poirot investigates by agatha christie london john lane the bodley head limited first published in great britain by john lane company the bodley head limited  copyright   agatha christie limited contents i the adventure of the western star ii the tragedy at marsdon manor iii the adventure of the cheap flat iv the mystery of hunters lodge v the million dollar bond robbery vi the adventure of the egyptian tomb vii jewel robbery at the grand metropolitan viii the kidnapped prime minister ix the disappearance of mr . davenheim x the adventure of the italian nobleman xi the case of the missing will poirot investigates poirot investigates i the adventure of the western star i was standing at the window of poirots rooms looking out idly on the street below . thats queer i ejaculated suddenly beneath my breath . what is mon ami ? asked poirot placidly from the depths of his comfortable chair . deduce poirot from the following facts here is a young lady richly dressedfashionable hat magnificent furs . she is coming along slowly looking up at the houses as she goes . unknown to her she is being shadowed by three men and a middleaged woman . they have just been joined by an errand boy who points after the girl gesticulating as he does so . what drama is this being played ? is the girl a crook and are the shadowers detectives preparing to arrest her ? or are they the scoundrels and are they plotting to attack an innocent victim ? what does the great detective say ? the great detective mon ami chooses as ever the simplest course . he rises to see for himself . and my friend joined me at the window . in a minute he gave vent to an amused chuckle . as usual your facts are tinged with your incurable romanticism . that is miss mary marvell the film star . she is being followed by a bevy of admirers who have recognized her . and en passant my dear hastings she is quite aware of the fact i laughed . so all is explained but you get no marks for that poirot . it was a mere matter of recognition . en vrit and how many times have you seen mary marvell on the screen mon cher ? i thought . about a dozen times perhaps . and ionce yet i recognize her and you do not . she looks so different i replied rather feebly . ah sacr cried poirot . is it that you expect her to promenade herself in the streets of london in a cowboy hat or with bare feet and a bunch of curls as an irish colleen ? always with you it is the nonessentials remember the case of the dancer valerie saintclair . i shrugged my shoulders slightly annoyed . but console yourself mon ami said poirot calming down . all cannot be as hercule poirot i know it well . you really have the best opinion of yourself of anyone i ever knew i cried divided between amusement and annoyance . what will you ? when one is unique one knows it and others share that opinioneven if i mistake not miss mary marvell . what ? without doubt . she is coming here . how do you make that out ? very simply . this street it is not aristocratic mon ami in it there is no fashionable doctor no fashionable dentiststill less is there a fashionable milliner but there is a fashionable detective . oui my friend it is truei am become the mode the dernier cri one says to another comment ? you have lost your gold pencilcase ? you must go to the little belgian . he is too marvellous every one goes courez and they arrive in flocks mon ami with problems of the most foolish a bell rang below . what did i tell you ? that is miss marvell . as usual poirot was right . after a short interval the american film star was ushered in and we rose to our feet . mary marvell was undoubtedly one of the most popular actresses on the screen . she had only lately arrived in england in company with her husband gregory b . rolf also a film actor . their marriage had taken place about a year ...

# %% [markdown]
# ### 2.2 Word Tokenization

# %% [markdown]
# #### 2.2.1 Tokenizer - no punctuation

# %%
# Tokenize text
tokenizer = Tokenizer(lower=False)
tokenizer.fit_on_texts([text_no_punctuation])
word_index_no = tokenizer.word_index
vocabulary_size_keras = len(word_index_no) + 1

# Save the tokenizer
with open('/content/drive/MyDrive/Deep learning model/Task3/tokenizer_no_punctuation.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
print("Vobaculary size:", vocabulary_size_keras)
# Out:
# Vobaculary size: 6264

# %%
word_index_no
# Out:
# {'the': 1,
#  'to': 2,
#  'a': 3,
#  'i': 4,
#  'of': 5,
#  'and': 6,
#  'in': 7,
#  'was': 8,
#  'he': 9,
#  'you': 10,
#  'it': 11,
#  'that': 12,
#  'is': 13,
#  'his': 14,
#  'poirot': 15,
#  'with': 16,
#  'not': 17,
#  'had': 18,
#  'but': 19,
#  'my': 20,
#  'at': 21,
#  'as': 22,
#  'have': 23,
#  'on': 24,
#  'we': 25,
#  'for': 26,
#  'me': 27,
#  'be': 28,
#  'him': 29,
#  'her': 30,
#  'one': 31,
#  'no': 32,
#  'from': 33,
#  'said': 34,
#  'there': 35,
#  'what': 36,
#  'she': 37,
#  'been': 38,
#  'all': 39,
#  'were': 40,
#  'by': 41,
#  'do': 42,
#  'this': 43,
#  'will': 44,
#  'mr': 45,
#  'an': 46,
#  'they': 47,
#  'so': 48,
#  'then': 49,
#  'man': 50,
#  'out': 51,
#  'are': 52,
#  'up': 53,
#  'would': 54,
#  'your': 55,
#  'did': 56,
#  'see': 57,
#  'about': 58,
#  'little': 59,
#  'which': 60,
#  'if': 61,
#  'has': 62,
#  'us': 63,
#  'who': 64,
#  'some': 65,
#  'well': 66,
#  'when': 67,
#  'our': 68,
#  'friend': 69,
#  'now': 70,
#  'must': 71,
#  'or': 72,
#  'into': 73,
#  'know': 74,
#  'hastings': 75,
#  'time': 76,
#  'them': 77,
#  'very': 78,
#  'mrs': 79,
#  'down': 80,
#  'door': 81,
#  'two': 82,
#  'its': 83,
#  'just': 84,
#  'monsieur': 85,
#  'head': 86,
#  'could': 87,
#  'here': 88,
#  'think': 89,
#  'any': 90,
#  'left': 91,
#  'good': 92,
#  'yes': 93,
#  'over': 94,
#  'once': 95,
#  'more': 96,
#  'can': 97,
#  'say': 98,
#  'after': 99,
#  'way': 100,
#  'am': 101,
#  'come': 102,
#  'room': 103,
#  'only': 104,
#  'came': 105,
#  'went': 106,
#  'before': 107,
#  'yardly': 108,
#  'should': 109,
#  'never': 110,
#  'few': 111,
#  'where': 112,
#  'mon': 113,
#  'back': 114,
#  'sir': 115,
#  'nothing': 116,
#  'japp': 117,
#  'london': 118,
#  'miss': 119,
#  'too': 120,
#  'much': 121,
#  'like': 122,
#  'lady': 123,
#  'how': 124,
#  'rather': 125,
#  'young': 126,
#  'go': 127,
#  'got': 128,
#  'why': 129,
#  'other': 130,
#  'made': 131,
#  'woman': 132,
#  'himself': 133,
#  'case': 134,
#  'quite': 135,
#  'make': 136,
#  'hand': 137,
#  'prime': 138,
#  'ami': 139,
#  'three': 140,
#  'may': 141,
#  'cried': 142,
#  'tell': 143,
#  'looked': 144,
#  'found': 145,
#  'get': 146,
#  'last': 147,
#  'right': 148,
#  'own': 149,
#  'police': 150,
#  'car': 151,
#  'first': 152,
#  'doctor': 153,
#  'let': 154,
#  'take': 155,
#  'face': 156,
#  'moment': 157,
#  'ah': 158,
#  'lord': 159,
#  'seemed': 160,
#  'took': 161,
#  'minister': 162,
#  'shall': 163,
#  'dont': 164,
#  'again': 165,
#  'saw': 166,
#  'same': 167,
#  'davenheim': 168,
#  'asked': 169,
#  'course': 170,
#  'through': 171,
#  'eyes': 172,
#  'find': 173,
#  'their': 174,
#  'old': 175,
#  'morning': 176,
#  'house': 177,
#  'upon': 178,
#  'new': 179,
#  'flat': 180,
#  'going': 181,
#  'oh': 182,
#  'poirots': 183,
#  'believe': 184,
#  'something': 185,
#  'round': 186,
#  'small': 187,
#  'than': 188,
#  'great': 189,
#  'another': 190,
#  'place': 191,
#  'put': 192,
#  'inspector': 193,
#  'being': 194,
#  'thought': 195,
#  'always': 196,
#  'these': 197,
#  'off': 198,
#  'away': 199,
#  'thing': 200,
#  'minutes': 201,
#  'matter': 202,
#  'madame': 203,
#  'havering': 204,
#  'thats': 205,
#  'fact': 206,
#  'most': 207,
#  'night': 208,
#  'still': 209,
#  'might': 210,
#  'story': 211,
#  'im': 212,
#  'turned': 213,
#  'black': 214,
#  'sure': 215,
#  'money': 216,
#  'york': 217,
#  'men': 218,
#  'without': 219,
#  'every': 220,
#  'captain': 221,
#  'day': 222,
#  'does': 223,
#  'husband': 224,
#  'eh': 225,
#  'myself': 226,
#  'maltravers': 227,
#  'dr': 228,
#  'uncle': 229,
#  'diamond': 230,
#  'bien': 231,
#  'returned': 232,
#  'question': 233,
#  'though': 234,
#  'light': 235,
#  'marvell': 236,
#  'yourself': 237,
#  'also': 238,
#  'taken': 239,
#  'name': 240,
#  'look': 241,
#  'shook': 242,
#  'understand': 243,
#  'even': 244,
#  'life': 245,
#  'suddenly': 246,
#  'arrived': 247,
#  'death': 248,
#  'leave': 249,
#  'words': 250,
#  'wife': 251,
#  'things': 252,
#  'work': 253,
#  'opalsen': 254,
#  'usual': 255,
#  'really': 256,
#  'england': 257,
#  'second': 258,
#  'long': 259,
#  'heard': 260,
#  'ive': 261,
#  'evening': 262,
#  'voice': 263,
#  'mind': 264,
#  'big': 265,
#  'shot': 266,
#  'mean': 267,
#  'sent': 268,
#  'far': 269,
#  'behind': 270,
#  'enough': 271,
#  'point': 272,
#  'road': 273,
#  'bonds': 274,
#  'window': 275,
#  'gave': 276,
#  'passed': 277,
#  'give': 278,
#  'gone': 279,
#  'side': 280,
#  'dinner': 281,
#  'dead': 282,
#  'late': 283,
#  'clear': 284,
#  'affair': 285,
#  'yet': 286,
#  'replied': 287,
#  'cannot': 288,
#  'knew': 289,
#  'doubt': 290,
#  'true': 291,
#  'next': 292,
#  'murmured': 293,
#  'want': 294,
#  'ask': 295,
#  'exactly': 296,
#  'told': 297,
#  'done': 298,
#  'hes': 299,
#  'suppose': 300,
#  'later': 301,
#  'such': 302,
#  'idea': 303,
#  'count': 304,
#  'france': 305,
#  'explained': 306,
#  'seen': 307,
#  'perhaps': 308,
#  'rolf': 309,
#  'return': 310,
#  'each': 311,
#  'anything': 312,
#  'soon': 313,
#  'figure': 314,
#  'key': 315,
#  'grey': 316,
#  'chambermaid': 317,
#  'facts': 318,
#  'ago': 319,
#  'handed': 320,
#  'years': 321,
#  'nodded': 322,
#  'almost': 323,
#  'curious': 324,
#  'half': 325,
#  'hands': 326,
#  'able': 327,
#  'hour': 328,
#  'appeared': 329,
#  'certainly': 330,
#  'part': 331,
#  'waiting': 332,
#  'certain': 333,
#  'willard': 334,
#  'minute': 335,
#  'many': 336,
#  'afraid': 337,
#  'brought': 338,
#  'possible': 339,
#  'open': 340,
#  'cant': 341,
#  'air': 342,
#  'heart': 343,
#  'held': 344,
#  'better': 345,
#  'scotland': 346,
#  'manner': 347,
#  'robinson': 348,
#  'daniels': 349,
#  'omurphy': 350,
#  'start': 351,
#  'star': 352,
#  'detective': 353,
#  'followed': 354,
#  'hercule': 355,
#  'says': 356,
#  'forward': 357,
#  'seems': 358,
#  'ill': 359,
#  'theres': 360,
#  'id': 361,
#  'received': 362,
#  'perfectly': 363,
#  'since': 364,
#  'method': 365,
#  'kind': 366,
#  'word': 367,
#  'gentleman': 368,
#  'oclock': 369,
#  'body': 370,
#  'station': 371,
#  'bleibner': 372,
#  'lowen': 373,
#  'murder': 374,
#  'looking': 375,
#  'ever': 376,
#  'remember': 377,
#  'given': 378,
#  'full': 379,
#  'safe': 380,
#  'pace': 381,
#  'large': 382,
#  'smiled': 383,
#  'having': 384,
#  'fellow': 385,
#  'hall': 386,
#  'stood': 387,
#  'friends': 388,
#  'necklace': 389,
#  'floor': 390,
#  'under': 391,
#  'yard': 392,
#  'study': 393,
#  'end': 394,
#  'those': 395,
#  'against': 396,
#  'housekeeper': 397,
#  'ridgeway': 398,
#  'italian': 399,
#  'mary': 400,
#  'letters': 401,
#  'god': 402,
#  'began': 403,
#  'business': 404,
#  'already': 405,
#  'table': 406,
#  'together': 407,
#  'entered': 408,
#  'opened': 409,
#  'immediately': 410,
#  'train': 411,
#  'bank': 412,
#  'norman': 413,
#  'present': 414,
#  'impossible': 415,
#  'both': 416,
#  'known': 417,
#  'observed': 418,
#  'papers': 419,
#  'tall': 420,
#  'world': 421,
#  'accompanied': 422,
#  'spoke': 423,
#  'continued': 424,
#  'telephone': 425,
#  'whole': 426,
#  'run': 427,
#  'started': 428,
#  'revolver': 429,
#  'search': 430,
#  'nobody': 431,
#  'clestine': 432,
#  'ascanio': 433,
#  'manor': 434,
#  'chair': 435,
#  'between': 436,
#  'bell': 437,
#  'rang': 438,
#  'rose': 439,
#  'stone': 440,
#  'details': 441,
#  'eye': 442,
#  'because': 443,
#  'days': 444,
#  'white': 445,
#  'lay': 446,
#  'stared': 447,
#  'need': 448,
#  'thank': 449,
#  'everything': 450,
#  'straight': 451,
#  'five': 452,
#  'smiling': 453,
#  'outside': 454,
#  'within': 455,
#  'gentlemen': 456,
#  'across': 457,
#  'lock': 458,
#  'crime': 459,
#  'master': 460,
#  'foscatini': 461,
#  'following': 462,
#  'laughed': 463,
#  'knows': 464,
#  'felt': 465,
#  'latter': 466,
#  'inside': 467,
#  'ran': 468,
#  'thoughtfully': 469,
#  'pray': 470,
#  'until': 471,
#  'pretty': 472,
#  'read': 473,
#  'suggested': 474,
#  'towards': 475,
#  'wire': 476,
#  'order': 477,
#  'getting': 478,
#  'remained': 479,
#  'near': 480,
#  'sitting': 481,
#  'answer': 482,
#  'indeed': 483,
#  'bound': 484,
#  'suicide': 485,
#  'blood': 486,
#  'card': 487,
#  'maid': 488,
#  'people': 489,
#  'cells': 490,
#  'ames': 491,
#  'pearls': 492,
#  'french': 493,
#  'dear': 494,
#  'different': 495,
#  'american': 496,
#  'gregory': 497,
#  'jewels': 498,
#  'sum': 499,
#  'talking': 500,
#  'hesitated': 501,
#  'permit': 502,
#  'locked': 503,
#  'surely': 504,
#  'chance': 505,
#  'real': 506,
#  'call': 507,
#  'sat': 508,
#  'mouth': 509,
#  'smile': 510,
#  'further': 511,
#  'tried': 512,
#  'town': 513,
#  'questions': 514,
#  'likely': 515,
#  'met': 516,
#  'telegram': 517,
#  'past': 518,
#  'turn': 519,
#  'however': 520,
#  'proved': 521,
#  'answered': 522,
#  'clever': 523,
#  'whom': 524,
#  'led': 525,
#  'didnt': 526,
#  'particular': 527,
#  'attention': 528,
#  'parker': 529,
#  'placed': 530,
#  'close': 531,
#  'ring': 532,
#  'signor': 533,
#  'coffee': 534,
#  'olympia': 535,
#  'philip': 536,
#  'estair': 537,
#  'marsh': 538,
#  'john': 539,
#  'jewel': 540,
#  'street': 541,
#  'coming': 542,
#  'along': 543,
#  'goes': 544,
#  'points': 545,
#  'girl': 546,
#  'feet': 547,
#  'less': 548,
#  'clothes': 549,
#  'fair': 550,
#  'drew': 551,
#  'dark': 552,
#  'carefully': 553,
#  'serious': 554,
#  'set': 555,
#  'jewelcase': 556,
#  'hotel': 557,
#  'hard': 558,
#  'appearance': 559,
#  'paper': 560,
#  'east': 561,
#  'stolen': 562,
#  'mine': 563,
#  'la': 564,
#  'youre': 565,
#  'demanded': 566,
#  'reply': 567,
#  'uttered': 568,
#  'fell': 569,
#  'note': 570,
#  'puzzled': 571,
#  'alone': 572,
#  'arm': 573,
#  'keep': 574,
#  'discovered': 575,
#  'poor': 576,
#  'hear': 577,
#  'tuesday': 578,
#  'news': 579,
#  'declared': 580,
#  'front': 581,
#  'fancy': 582,
#  'couldnt': 583,
#  'nephew': 584,
#  'opalsens': 585,
#  'drawer': 586,
#  'robbery': 587,
#  'tomb': 588,
#  'standing': 589,
#  'magnificent': 590,
#  'slowly': 591,
#  'times': 592,
#  'short': 593,
#  'post': 594,
#  'finished': 595,
#  'slight': 596,
#  'thin': 597,
#  'meet': 598,
#  'description': 599,
#  'stopped': 600,
#  'anyway': 601,
#  'shes': 602,
#  'bowed': 603,
#  'home': 604,
#  'occurred': 605,
#  'milord': 606,
#  'finger': 607,
#  'gesture': 608,
#  'plan': 609,
#  'wanted': 610,
#  'trouble': 611,
#  'hair': 612,
#  'reason': 613,
#  'feel': 614,
#  'tonight': 615,
#  'low': 616,
#  'happened': 617,
#  'impatiently': 618,
#  'brain': 619,
#  'guy': 620,
#  'remarked': 621,
#  'four': 622,
#  'gently': 623,
#  'begin': 624,
#  'truth': 625,
#  'upstairs': 626,
#  'hardly': 627,
#  'beginning': 628,
#  'absolutely': 629,
#  'eight': 630,
#  'walked': 631,
#  'speak': 632,
#  'quickly': 633,
#  'quick': 634,
#  'stepped': 635,
#  'clearly': 636,
#  'care': 637,
#  'hold': 638,
#  'several': 639,
#  'lift': 640,
#  'various': 641,
#  'six': 642,
#  'interest': 643,
#  'disappeared': 644,
#  'whilst': 645,
#  'escape': 646,
#  'glance': 647,
#  'cat': 648,
#  'beard': 649,
#  'evidence': 650,
#  'sea': 651,
#  'cross': 652,
#  'package': 653,
#  'egypt': 654,
#  'tosswill': 655,
#  'tent': 656,
#  'valet': 657,
#  'mystery': 658,
#  'hunters': 659,
#  'lodge': 660,
#  'missing': 661,
#  'breath': 662,
#  'recognized': 663,
#  'herself': 664,
#  'anyone': 665,
#  'mistake': 666,
#  'prepared': 667,
#  'rapidly': 668,
#  'paused': 669,
#  'envelope': 670,
#  'letter': 671,
#  'information': 672,
#  'leaves': 673,
#  'therefore': 674,
#  'bow': 675,
#  'paid': 676,
#  'whether': 677,
#  'taking': 678,
#  'wait': 679,
#  'country': 680,
#  'saying': 681,
#  'strange': 682,
#  'incredible': 683,
#  'pleased': 684,
#  'least': 685,
#  'pass': 686,
#  'tomorrow': 687,
#  'briskly': 688,
#  'catch': 689,
#  'brief': 690,
#  'while': 691,
#  'thief': 692,
#  'ordinary': 693,
#  'easy': 694,
#  'force': 695,
#  'leaving': 696,
#  'taxi': 697,
#  'office': 698,
#  'merely': 699,
#  'use': 700,
#  'inquiries': 701,
#  'object': 702,
#  'kept': 703,
#  'forced': 704,
#  'perfect': 705,
#  'afterwards': 706,
#  'called': 707,
#  'examined': 708,
#  'although': 709,
#  'itself': 710,
#  'remarkable': 711,
#  'position': 712,
#  'local': 713,
#  'ourselves': 714,
#  'main': 715,
#  'charming': 716,
#  'rifle': 717,
#  'mistress': 718,
#  'afternoon': 719,
#  'village': 720,
#  'watch': 721,
#  'hours': 722,
#  'hope': 723,
#  'isnt': 724,
#  'obviously': 725,
#  'finally': 726,
#  'empty': 727,
#  'neat': 728,
#  'somewhat': 729,
#  'spot': 730,
#  'farquhar': 731,
#  'mademoiselle': 732,
#  'arrested': 733,
#  'chauffeur': 734,
#  'baker': 735,
#  'secret': 736,
#  'company': 737,
#  'adventure': 738,
#  'rooms': 739,
#  'placidly': 740,
#  'expect': 741,
#  'slightly': 742,
#  'best': 743,
#  'become': 744,
#  'ushered': 745,
#  'year': 746,
#  'insured': 747,
#  'telling': 748,
#  'comprehend': 749,
#  'chinaman': 750,
#  'please': 751,
#  'chase': 752,
#  'interested': 753,
#  'pardon': 754,
#  'luck': 755,
#  'fear': 756,
#  'angrily': 757,
#  'returning': 758,
#  'de': 759,
#  'spite': 760,
#  'wont': 761,
#  'women': 762,
#  'removed': 763,
#  'wish': 764,
#  'sprang': 765,
#  'wall': 766,
#  'evidently': 767,
#  'fetch': 768,
#  'aside': 769,
#  'unusual': 770,
#  'theory': 771,
#  'moments': 772,
#  'clerk': 773,
#  'noticed': 774,
#  'bring': 775,
#  'makes': 776,
#  'ingenious': 777,
#  'insurance': 778,
#  'concealed': 779,
#  'cause': 780,
#  'bernard': 781,
#  'pleasant': 782,
#  'lips': 783,
#  'rook': 784,
#  'recent': 785,
#  'bullet': 786,
#  'became': 787,
#  'showed': 788,
#  'drive': 789,
#  'sign': 790,
#  'asking': 791,
#  'help': 792,
#  'boat': 793,
#  'pocket': 794,
#  'shaw': 795,
#  'superstition': 796,
#  'shut': 797,
#  'bed': 798,
#  'grave': 799,
#  'flats': 800,
#  'occupied': 801,
#  'interrupted': 802,
#  'months': 803,
#  'elsa': 804,
#  'service': 805,
#  'surprise': 806,
#  'middleton': 807,
#  'contained': 808,
#  'fortune': 809,
#  'vavasour': 810,
#  'manager': 811,
#  'hidden': 812,
#  'officer': 813,
#  'harper': 814,
#  'court': 815,
#  'dodge': 816,
#  'conference': 817,
#  'ministers': 818,
#  'major': 819,
#  'plates': 820,
#  'western': 821,
#  'ii': 822,
#  'marsdon': 823,
#  'metropolitan': 824,
#  'disappearance': 825,
#  'middleaged': 826,
#  'film': 827,
#  'looks': 828,
#  'others': 829,
#  'wonderful': 830,
#  'written': 831,
#  'famous': 832,
#  'friday': 833,
#  'seek': 834,
#  'carry': 835,
#  'today': 836,
#  'pas': 837,
#  'none': 838,
#  'show': 839,
#  'pleasure': 840,
#  'amongst': 841,
#  'either': 842,
#  'interesting': 843,
#  'problem': 844,
#  'sharply': 845,
#  'beg': 846,
#  'seeing': 847,
#  'bolt': 848,
#  'events': 849,
#  'during': 850,
#  'inclined': 851,
#  'top': 852,
#  'war': 853,
#  'satisfaction': 854,
#  'observe': 855,
#  'extraordinary': 856,
#  'odd': 857,
#  'comes': 858,
#  'send': 859,
#  'theyre': 860,
#  'alive': 861,
#  'piece': 862,
#  'excellent': 863,
#  'entirely': 864,
#  'suspect': 865,
#  'bit': 866,
#  'notice': 867,
#  'watched': 868,
#  'necessary': 869,
#  'wished': 870,
#  'struck': 871,
#  'passage': 872,
#  'duplicate': 873,
#  'offered': 874,
#  'jumped': 875,
#  'decided': 876,
#  'admit': 877,
#  'seem': 878,
#  'sound': 879,
#  'committed': 880,
#  'considerable': 881,
#  'lying': 882,
#  'parlourmaid': 883,
#  'husbands': 884,
#  'recount': 885,
#  'pressed': 886,
#  'fired': 887,
#  'general': 888,
#  'died': 889,
#  'bad': 890,
#  'possibly': 891,
#  'le': 892,
#  'anxious': 893,
#  'talk': 894,
#  'closed': 895,
#  'somewhere': 896,
#  'whisper': 897,
#  'sort': 898,
#  'else': 899,
#  'view': 900,
#  'means': 901,
#  'apparently': 902,
#  'wellknown': 903,
#  'wrong': 904,
#  'excuse': 905,
#  'quarter': 906,
#  'sunday': 907,
#  'drawn': 908,
#  'hardt': 909,
#  'doing': 910,
#  'living': 911,
#  'moved': 912,
#  'roger': 913,
#  'son': 914,
#  'charge': 915,
#  'nine': 916,
#  'murderer': 917,
#  'nevertheless': 918,
#  'alibi': 919,
#  'science': 920,
#  'result': 921,
#  'thrown': 922,
#  'secretary': 923,
#  'ended': 924,
#  'sand': 925,
#  'tetanus': 926,
#  'workmen': 927,
#  'successful': 928,
#  'saturday': 929,
#  'macadam': 930,
#  'firm': 931,
#  'lake': 932,
#  'dishes': 933,
#  'graves': 934,
#  'desk': 935,
#  'cheap': 936,
#  'egyptian': 937,
#  'nobleman': 938,
#  'ejaculated': 939,
#  'beneath': 940,
#  'hat': 941,
#  'joined': 942,
#  'played': 943,
#  'shrugged': 944,
#  'shoulders': 945,
#  'arrive': 946,
#  'undoubtedly': 947,
#  'visit': 948,
#  'pounds': 949,
#  'proceed': 950,
#  'closely': 951,
#  'address': 952,
#  'terms': 953,
#  'moon': 954,
#  'wonder': 955,
#  'attached': 956,
#  'turning': 957,
#  'date': 958,
#  'fire': 959,
#  'rule': 960,
#  'weve': 961,
#  'deal': 962,
#  'places': 963,
#  'guess': 964,
#  'society': 965,
#  'possession': 966,
#  'family': 967,
#  'till': 968,
#  'coincidence': 969,
#  'fancied': 970,
#  'dryly': 971,
#  'bear': 972,
#  'landlady': 973,
#  'tapped': 974,
#  'often': 975,
#  'thanked': 976,
#  'gasped': 977,
#  'series': 978,
#  'nature': 979,
#  'unfortunately': 980,
#  'absence': 981,
#  'conversation': 982,
#  'conceal': 983,
#  'south': 984,
#  'tout': 985,
#  'actually': 986,
#  'live': 987,
#  'investigate': 988,
#  'youll': 989,
#  'failed': 990,
#  'neck': 991,
#  'vanished': 992,
#  'piercing': 993,
#  'rushed': 994,
#  'sight': 995,
#  'caught': 996,
#  'dieu': 997,
#  'usually': 998,
#  'wits': 999,
#  'departed': 1000,
#  ...}

# %% [markdown]
# #### 2.2.2 Tokenizer - with punctuation

# %%
# Tokenize text
tokenizer = Tokenizer(filters='')
tokenizer.fit_on_texts([text_with_punctuation])
word_index_punc = tokenizer.word_index
vocabulary_size_punc = len(word_index_punc) + 1

# Save the tokenizer
with open('/content/drive/MyDrive/Deep learning model/Task3/tokenizer_with_punctuation.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
print("Vobaculary size:", vocabulary_size_punc)
# Out:
# Vobaculary size: 6272

# %%
word_index_punc
# Out:
# {'.': 1,
#  'the': 2,
#  'to': 3,
#  'a': 4,
#  'i': 5,
#  'of': 6,
#  'and': 7,
#  'in': 8,
#  'was': 9,
#  'he': 10,
#  'you': 11,
#  'it': 12,
#  'that': 13,
#  '?': 14,
#  'is': 15,
#  'his': 16,
#  'poirot': 17,
#  'with': 18,
#  'not': 19,
#  'had': 20,
#  'but': 21,
#  'my': 22,
#  'at': 23,
#  'as': 24,
#  'have': 25,
#  'on': 26,
#  'we': 27,
#  'for': 28,
#  'me': 29,
#  'be': 30,
#  'him': 31,
#  'her': 32,
#  'one': 33,
#  'no': 34,
#  'from': 35,
#  'said': 36,
#  'there': 37,
#  'what': 38,
#  'she': 39,
#  'been': 40,
#  'all': 41,
#  'were': 42,
#  'by': 43,
#  'do': 44,
#  'this': 45,
#  'will': 46,
#  'mr': 47,
#  'an': 48,
#  'they': 49,
#  'so': 50,
#  'then': 51,
#  'man': 52,
#  'out': 53,
#  'are': 54,
#  'up': 55,
#  'would': 56,
#  'your': 57,
#  'did': 58,
#  'see': 59,
#  'about': 60,
#  'little': 61,
#  'which': 62,
#  'if': 63,
#  'has': 64,
#  'us': 65,
#  'who': 66,
#  'some': 67,
#  'well': 68,
#  'when': 69,
#  'our': 70,
#  'friend': 71,
#  'now': 72,
#  'must': 73,
#  'or': 74,
#  'into': 75,
#  'know': 76,
#  'hastings': 77,
#  'time': 78,
#  'them': 79,
#  'very': 80,
#  'mrs': 81,
#  'down': 82,
#  'door': 83,
#  'two': 84,
#  'its': 85,
#  'just': 86,
#  'monsieur': 87,
#  'head': 88,
#  'could': 89,
#  'think': 90,
#  'here': 91,
#  'any': 92,
#  'left': 93,
#  'good': 94,
#  'yes': 95,
#  'over': 96,
#  'once': 97,
#  'more': 98,
#  'can': 99,
#  'say': 100,
#  'after': 101,
#  'way': 102,
#  'am': 103,
#  'come': 104,
#  'room': 105,
#  'only': 106,
#  'came': 107,
#  'went': 108,
#  'before': 109,
#  'yardly': 110,
#  'should': 111,
#  'never': 112,
#  'few': 113,
#  'where': 114,
#  'mon': 115,
#  'back': 116,
#  'sir': 117,
#  'nothing': 118,
#  'japp': 119,
#  'london': 120,
#  'miss': 121,
#  'too': 122,
#  'much': 123,
#  'like': 124,
#  'lady': 125,
#  'how': 126,
#  'rather': 127,
#  'young': 128,
#  'go': 129,
#  'got': 130,
#  'why': 131,
#  'other': 132,
#  'made': 133,
#  'woman': 134,
#  'himself': 135,
#  'case': 136,
#  'quite': 137,
#  'make': 138,
#  'hand': 139,
#  'prime': 140,
#  'ami': 141,
#  'three': 142,
#  'may': 143,
#  'cried': 144,
#  'tell': 145,
#  'looked': 146,
#  'found': 147,
#  'get': 148,
#  'last': 149,
#  'right': 150,
#  'own': 151,
#  'police': 152,
#  'car': 153,
#  'first': 154,
#  'doctor': 155,
#  'let': 156,
#  'take': 157,
#  'face': 158,
#  'moment': 159,
#  'ah': 160,
#  'lord': 161,
#  'seemed': 162,
#  'took': 163,
#  'minister': 164,
#  'shall': 165,
#  'dont': 166,
#  'again': 167,
#  'saw': 168,
#  'same': 169,
#  'davenheim': 170,
#  'asked': 171,
#  'course': 172,
#  'through': 173,
#  'eyes': 174,
#  'find': 175,
#  'house': 176,
#  'their': 177,
#  'old': 178,
#  'morning': 179,
#  'upon': 180,
#  'new': 181,
#  'flat': 182,
#  'going': 183,
#  'oh': 184,
#  'poirots': 185,
#  'believe': 186,
#  'something': 187,
#  'round': 188,
#  'small': 189,
#  'than': 190,
#  'great': 191,
#  'another': 192,
#  'place': 193,
#  'put': 194,
#  'inspector': 195,
#  'being': 196,
#  'thought': 197,
#  'always': 198,
#  'these': 199,
#  'off': 200,
#  'away': 201,
#  'thing': 202,
#  'minutes': 203,
#  'matter': 204,
#  'madame': 205,
#  'havering': 206,
#  'thats': 207,
#  'fact': 208,
#  'most': 209,
#  'night': 210,
#  'still': 211,
#  'might': 212,
#  'story': 213,
#  'im': 214,
#  'turned': 215,
#  'black': 216,
#  'sure': 217,
#  'money': 218,
#  'york': 219,
#  'men': 220,
#  'without': 221,
#  'every': 222,
#  'captain': 223,
#  'day': 224,
#  'does': 225,
#  'husband': 226,
#  'eh': 227,
#  'myself': 228,
#  'maltravers': 229,
#  'dr': 230,
#  'uncle': 231,
#  'diamond': 232,
#  'bien': 233,
#  'returned': 234,
#  'question': 235,
#  'though': 236,
#  'light': 237,
#  'marvell': 238,
#  'yourself': 239,
#  'also': 240,
#  'taken': 241,
#  'name': 242,
#  'look': 243,
#  'shook': 244,
#  'understand': 245,
#  'even': 246,
#  'life': 247,
#  'suddenly': 248,
#  'arrived': 249,
#  'death': 250,
#  'leave': 251,
#  'words': 252,
#  'wife': 253,
#  'things': 254,
#  'work': 255,
#  'opalsen': 256,
#  'usual': 257,
#  'really': 258,
#  'england': 259,
#  'second': 260,
#  'long': 261,
#  'heard': 262,
#  'ive': 263,
#  'evening': 264,
#  'voice': 265,
#  'mind': 266,
#  'big': 267,
#  'shot': 268,
#  'mean': 269,
#  'sent': 270,
#  'far': 271,
#  'behind': 272,
#  'enough': 273,
#  'point': 274,
#  'road': 275,
#  'bonds': 276,
#  'window': 277,
#  'gave': 278,
#  'passed': 279,
#  'give': 280,
#  'gone': 281,
#  'side': 282,
#  'dinner': 283,
#  'dead': 284,
#  'late': 285,
#  'clear': 286,
#  'affair': 287,
#  'yet': 288,
#  'replied': 289,
#  'cannot': 290,
#  'knew': 291,
#  'doubt': 292,
#  'true': 293,
#  'next': 294,
#  'murmured': 295,
#  'want': 296,
#  'ask': 297,
#  'exactly': 298,
#  'told': 299,
#  'done': 300,
#  'hes': 301,
#  'suppose': 302,
#  'later': 303,
#  'such': 304,
#  'idea': 305,
#  'count': 306,
#  'france': 307,
#  'explained': 308,
#  'seen': 309,
#  'perhaps': 310,
#  'rolf': 311,
#  'return': 312,
#  'each': 313,
#  'anything': 314,
#  'soon': 315,
#  'figure': 316,
#  'key': 317,
#  'grey': 318,
#  'chambermaid': 319,
#  'facts': 320,
#  'ago': 321,
#  'handed': 322,
#  'years': 323,
#  'nodded': 324,
#  'almost': 325,
#  'curious': 326,
#  'half': 327,
#  'hands': 328,
#  'able': 329,
#  'hour': 330,
#  'appeared': 331,
#  'certainly': 332,
#  'part': 333,
#  'waiting': 334,
#  'certain': 335,
#  'willard': 336,
#  'minute': 337,
#  'many': 338,
#  'afraid': 339,
#  'brought': 340,
#  'possible': 341,
#  'open': 342,
#  'cant': 343,
#  'air': 344,
#  'heart': 345,
#  'held': 346,
#  'better': 347,
#  'scotland': 348,
#  'manner': 349,
#  'robinson': 350,
#  'daniels': 351,
#  'omurphy': 352,
#  'start': 353,
#  'star': 354,
#  'detective': 355,
#  'followed': 356,
#  'hercule': 357,
#  'says': 358,
#  'forward': 359,
#  'seems': 360,
#  'ill': 361,
#  'theres': 362,
#  'id': 363,
#  'received': 364,
#  'perfectly': 365,
#  'since': 366,
#  'method': 367,
#  'kind': 368,
#  'word': 369,
#  'gentleman': 370,
#  'oclock': 371,
#  'body': 372,
#  'station': 373,
#  'bleibner': 374,
#  'lowen': 375,
#  'murder': 376,
#  'looking': 377,
#  'ever': 378,
#  'remember': 379,
#  'given': 380,
#  'full': 381,
#  'safe': 382,
#  'pace': 383,
#  'large': 384,
#  'smiled': 385,
#  'having': 386,
#  'fellow': 387,
#  'hall': 388,
#  'stood': 389,
#  'friends': 390,
#  'necklace': 391,
#  'floor': 392,
#  'under': 393,
#  'yard': 394,
#  'study': 395,
#  'end': 396,
#  'those': 397,
#  'against': 398,
#  'housekeeper': 399,
#  'ridgeway': 400,
#  'italian': 401,
#  'mary': 402,
#  'letters': 403,
#  'god': 404,
#  'began': 405,
#  'business': 406,
#  'already': 407,
#  'table': 408,
#  'together': 409,
#  'entered': 410,
#  'opened': 411,
#  'immediately': 412,
#  'train': 413,
#  'bank': 414,
#  'norman': 415,
#  'present': 416,
#  'impossible': 417,
#  'both': 418,
#  'known': 419,
#  'observed': 420,
#  'papers': 421,
#  'tall': 422,
#  'world': 423,
#  'accompanied': 424,
#  'spoke': 425,
#  'continued': 426,
#  'telephone': 427,
#  'whole': 428,
#  'run': 429,
#  'started': 430,
#  'revolver': 431,
#  'search': 432,
#  'nobody': 433,
#  'clestine': 434,
#  'ascanio': 435,
#  'manor': 436,
#  'chair': 437,
#  'between': 438,
#  'bell': 439,
#  'rang': 440,
#  'rose': 441,
#  'stone': 442,
#  'details': 443,
#  'eye': 444,
#  'because': 445,
#  'days': 446,
#  'white': 447,
#  'lay': 448,
#  'stared': 449,
#  'need': 450,
#  'thank': 451,
#  'everything': 452,
#  'straight': 453,
#  'five': 454,
#  'smiling': 455,
#  'outside': 456,
#  'within': 457,
#  'gentlemen': 458,
#  'across': 459,
#  'lock': 460,
#  'crime': 461,
#  'master': 462,
#  'foscatini': 463,
#  'following': 464,
#  'laughed': 465,
#  'knows': 466,
#  'felt': 467,
#  'latter': 468,
#  'inside': 469,
#  'ran': 470,
#  'thoughtfully': 471,
#  'pray': 472,
#  'until': 473,
#  'pretty': 474,
#  'read': 475,
#  'suggested': 476,
#  'towards': 477,
#  'wire': 478,
#  'order': 479,
#  'getting': 480,
#  'remained': 481,
#  'near': 482,
#  'sitting': 483,
#  'answer': 484,
#  'indeed': 485,
#  'bound': 486,
#  'suicide': 487,
#  'blood': 488,
#  'card': 489,
#  'maid': 490,
#  'people': 491,
#  'cells': 492,
#  'ames': 493,
#  'pearls': 494,
#  'french': 495,
#  'dear': 496,
#  'different': 497,
#  'american': 498,
#  'gregory': 499,
#  'jewels': 500,
#  'sum': 501,
#  'talking': 502,
#  'hesitated': 503,
#  'permit': 504,
#  'locked': 505,
#  'surely': 506,
#  'chance': 507,
#  'real': 508,
#  'call': 509,
#  'sat': 510,
#  'mouth': 511,
#  'smile': 512,
#  'further': 513,
#  'tried': 514,
#  'town': 515,
#  'questions': 516,
#  'likely': 517,
#  'met': 518,
#  'telegram': 519,
#  'past': 520,
#  'turn': 521,
#  'however': 522,
#  'proved': 523,
#  'answered': 524,
#  'clever': 525,
#  'whom': 526,
#  'led': 527,
#  'didnt': 528,
#  'particular': 529,
#  'attention': 530,
#  'parker': 531,
#  'placed': 532,
#  'close': 533,
#  'ring': 534,
#  'signor': 535,
#  'coffee': 536,
#  'olympia': 537,
#  'philip': 538,
#  'estair': 539,
#  'marsh': 540,
#  'john': 541,
#  'jewel': 542,
#  'street': 543,
#  'coming': 544,
#  'along': 545,
#  'goes': 546,
#  'points': 547,
#  'girl': 548,
#  'feet': 549,
#  'less': 550,
#  'clothes': 551,
#  'fair': 552,
#  'drew': 553,
#  'dark': 554,
#  'carefully': 555,
#  'serious': 556,
#  'set': 557,
#  'jewelcase': 558,
#  'hotel': 559,
#  'hard': 560,
#  'appearance': 561,
#  'paper': 562,
#  'east': 563,
#  'stolen': 564,
#  'mine': 565,
#  'la': 566,
#  'youre': 567,
#  'demanded': 568,
#  'reply': 569,
#  'uttered': 570,
#  'fell': 571,
#  'note': 572,
#  'puzzled': 573,
#  'alone': 574,
#  'arm': 575,
#  'keep': 576,
#  'discovered': 577,
#  'poor': 578,
#  'hear': 579,
#  'tuesday': 580,
#  'news': 581,
#  'declared': 582,
#  'front': 583,
#  'fancy': 584,
#  'couldnt': 585,
#  'nephew': 586,
#  'opalsens': 587,
#  'drawer': 588,
#  'robbery': 589,
#  'tomb': 590,
#  'standing': 591,
#  'magnificent': 592,
#  'slowly': 593,
#  'times': 594,
#  'short': 595,
#  'post': 596,
#  'finished': 597,
#  'slight': 598,
#  'thin': 599,
#  'meet': 600,
#  'description': 601,
#  'stopped': 602,
#  'anyway': 603,
#  'shes': 604,
#  'bowed': 605,
#  'home': 606,
#  'occurred': 607,
#  'milord': 608,
#  'finger': 609,
#  'gesture': 610,
#  'plan': 611,
#  'wanted': 612,
#  'trouble': 613,
#  'hair': 614,
#  'reason': 615,
#  'feel': 616,
#  'tonight': 617,
#  'low': 618,
#  'happened': 619,
#  'impatiently': 620,
#  'brain': 621,
#  'guy': 622,
#  'remarked': 623,
#  'four': 624,
#  'gently': 625,
#  'begin': 626,
#  'truth': 627,
#  'upstairs': 628,
#  'hardly': 629,
#  'beginning': 630,
#  'absolutely': 631,
#  'eight': 632,
#  'walked': 633,
#  'speak': 634,
#  'quickly': 635,
#  'quick': 636,
#  'stepped': 637,
#  'clearly': 638,
#  'care': 639,
#  'hold': 640,
#  'several': 641,
#  'lift': 642,
#  'various': 643,
#  'six': 644,
#  'interest': 645,
#  'disappeared': 646,
#  'whilst': 647,
#  'escape': 648,
#  'glance': 649,
#  'cat': 650,
#  'beard': 651,
#  'evidence': 652,
#  'sea': 653,
#  'cross': 654,
#  'package': 655,
#  'egypt': 656,
#  'tosswill': 657,
#  'tent': 658,
#  'valet': 659,
#  'mystery': 660,
#  'hunters': 661,
#  'lodge': 662,
#  'missing': 663,
#  'breath': 664,
#  'recognized': 665,
#  'herself': 666,
#  'anyone': 667,
#  'mistake': 668,
#  'prepared': 669,
#  'rapidly': 670,
#  'paused': 671,
#  'envelope': 672,
#  'letter': 673,
#  'information': 674,
#  'leaves': 675,
#  'therefore': 676,
#  'bow': 677,
#  'paid': 678,
#  'whether': 679,
#  'taking': 680,
#  'wait': 681,
#  'country': 682,
#  'saying': 683,
#  'strange': 684,
#  'incredible': 685,
#  'pleased': 686,
#  'least': 687,
#  'pass': 688,
#  'tomorrow': 689,
#  'briskly': 690,
#  'catch': 691,
#  'brief': 692,
#  'while': 693,
#  'thief': 694,
#  'ordinary': 695,
#  'easy': 696,
#  'force': 697,
#  'leaving': 698,
#  'taxi': 699,
#  'office': 700,
#  'merely': 701,
#  'use': 702,
#  'inquiries': 703,
#  'object': 704,
#  'kept': 705,
#  'forced': 706,
#  'perfect': 707,
#  'afterwards': 708,
#  'called': 709,
#  'examined': 710,
#  'although': 711,
#  'itself': 712,
#  'remarkable': 713,
#  'position': 714,
#  'local': 715,
#  'ourselves': 716,
#  'main': 717,
#  'charming': 718,
#  'rifle': 719,
#  'mistress': 720,
#  'afternoon': 721,
#  'village': 722,
#  'watch': 723,
#  'hours': 724,
#  'hope': 725,
#  'isnt': 726,
#  'obviously': 727,
#  'finally': 728,
#  'empty': 729,
#  'neat': 730,
#  'somewhat': 731,
#  'spot': 732,
#  'farquhar': 733,
#  'mademoiselle': 734,
#  'arrested': 735,
#  'chauffeur': 736,
#  'baker': 737,
#  'secret': 738,
#  'company': 739,
#  'adventure': 740,
#  'rooms': 741,
#  'placidly': 742,
#  'expect': 743,
#  'slightly': 744,
#  'best': 745,
#  'become': 746,
#  'ushered': 747,
#  'year': 748,
#  'insured': 749,
#  'telling': 750,
#  'comprehend': 751,
#  'chinaman': 752,
#  'please': 753,
#  'chase': 754,
#  'interested': 755,
#  'pardon': 756,
#  'luck': 757,
#  'fear': 758,
#  'angrily': 759,
#  'returning': 760,
#  'de': 761,
#  'spite': 762,
#  'wont': 763,
#  'women': 764,
#  'removed': 765,
#  'wish': 766,
#  'sprang': 767,
#  'wall': 768,
#  'evidently': 769,
#  'fetch': 770,
#  'aside': 771,
#  'unusual': 772,
#  'theory': 773,
#  'moments': 774,
#  'clerk': 775,
#  'noticed': 776,
#  'bring': 777,
#  'makes': 778,
#  'ingenious': 779,
#  'insurance': 780,
#  'concealed': 781,
#  'cause': 782,
#  'bernard': 783,
#  'pleasant': 784,
#  'lips': 785,
#  'rook': 786,
#  'recent': 787,
#  'bullet': 788,
#  'became': 789,
#  'showed': 790,
#  'drive': 791,
#  'sign': 792,
#  'asking': 793,
#  'help': 794,
#  'boat': 795,
#  'pocket': 796,
#  'shaw': 797,
#  'superstition': 798,
#  'shut': 799,
#  'bed': 800,
#  'grave': 801,
#  'flats': 802,
#  'occupied': 803,
#  'interrupted': 804,
#  'months': 805,
#  'elsa': 806,
#  'service': 807,
#  'surprise': 808,
#  'middleton': 809,
#  'contained': 810,
#  'fortune': 811,
#  'vavasour': 812,
#  'manager': 813,
#  'hidden': 814,
#  'officer': 815,
#  'harper': 816,
#  'court': 817,
#  'dodge': 818,
#  'conference': 819,
#  'ministers': 820,
#  'major': 821,
#  'plates': 822,
#  'western': 823,
#  'ii': 824,
#  'marsdon': 825,
#  'metropolitan': 826,
#  'disappearance': 827,
#  'middleaged': 828,
#  'film': 829,
#  'looks': 830,
#  'others': 831,
#  'wonderful': 832,
#  'written': 833,
#  'famous': 834,
#  'friday': 835,
#  'seek': 836,
#  'carry': 837,
#  'today': 838,
#  'pas': 839,
#  'none': 840,
#  'show': 841,
#  'pleasure': 842,
#  'amongst': 843,
#  'either': 844,
#  'interesting': 845,
#  'problem': 846,
#  'sharply': 847,
#  'beg': 848,
#  'seeing': 849,
#  'bolt': 850,
#  'events': 851,
#  'during': 852,
#  'inclined': 853,
#  'top': 854,
#  'war': 855,
#  'satisfaction': 856,
#  'observe': 857,
#  'extraordinary': 858,
#  'odd': 859,
#  'comes': 860,
#  'send': 861,
#  'theyre': 862,
#  'alive': 863,
#  'piece': 864,
#  'excellent': 865,
#  'entirely': 866,
#  'suspect': 867,
#  'bit': 868,
#  'notice': 869,
#  'watched': 870,
#  'necessary': 871,
#  'wished': 872,
#  'struck': 873,
#  'passage': 874,
#  'duplicate': 875,
#  'offered': 876,
#  'jumped': 877,
#  'decided': 878,
#  'admit': 879,
#  'seem': 880,
#  'sound': 881,
#  'committed': 882,
#  'considerable': 883,
#  'lying': 884,
#  'parlourmaid': 885,
#  'husbands': 886,
#  'recount': 887,
#  'pressed': 888,
#  'fired': 889,
#  'general': 890,
#  'died': 891,
#  'bad': 892,
#  'possibly': 893,
#  'le': 894,
#  'anxious': 895,
#  'talk': 896,
#  'closed': 897,
#  'somewhere': 898,
#  'whisper': 899,
#  'sort': 900,
#  'else': 901,
#  'view': 902,
#  'means': 903,
#  'apparently': 904,
#  'wellknown': 905,
#  'wrong': 906,
#  'excuse': 907,
#  'quarter': 908,
#  'sunday': 909,
#  'drawn': 910,
#  'hardt': 911,
#  'doing': 912,
#  'living': 913,
#  'moved': 914,
#  'roger': 915,
#  'son': 916,
#  'charge': 917,
#  'nine': 918,
#  'murderer': 919,
#  'nevertheless': 920,
#  'alibi': 921,
#  'science': 922,
#  'result': 923,
#  'thrown': 924,
#  'secretary': 925,
#  'ended': 926,
#  'sand': 927,
#  'tetanus': 928,
#  'workmen': 929,
#  'successful': 930,
#  'saturday': 931,
#  'macadam': 932,
#  'firm': 933,
#  'lake': 934,
#  'dishes': 935,
#  'graves': 936,
#  'desk': 937,
#  'cheap': 938,
#  'egyptian': 939,
#  'nobleman': 940,
#  'ejaculated': 941,
#  'beneath': 942,
#  'hat': 943,
#  'joined': 944,
#  'played': 945,
#  'shrugged': 946,
#  'shoulders': 947,
#  'arrive': 948,
#  'undoubtedly': 949,
#  'visit': 950,
#  'pounds': 951,
#  'proceed': 952,
#  'closely': 953,
#  'address': 954,
#  'terms': 955,
#  'moon': 956,
#  'wonder': 957,
#  'attached': 958,
#  'turning': 959,
#  'date': 960,
#  'fire': 961,
#  'rule': 962,
#  'weve': 963,
#  'deal': 964,
#  'places': 965,
#  'guess': 966,
#  'society': 967,
#  'possession': 968,
#  'family': 969,
#  'till': 970,
#  'coincidence': 971,
#  'fancied': 972,
#  'dryly': 973,
#  'bear': 974,
#  'landlady': 975,
#  'tapped': 976,
#  'often': 977,
#  'thanked': 978,
#  'gasped': 979,
#  'series': 980,
#  'nature': 981,
#  'unfortunately': 982,
#  'absence': 983,
#  'conversation': 984,
#  'conceal': 985,
#  'south': 986,
#  'tout': 987,
#  'actually': 988,
#  'live': 989,
#  'investigate': 990,
#  'youll': 991,
#  'failed': 992,
#  'neck': 993,
#  'vanished': 994,
#  'piercing': 995,
#  'rushed': 996,
#  'sight': 997,
#  'caught': 998,
#  'dieu': 999,
#  'usually': 1000,
#  ...}

# %% [markdown]
# ### 2.3 Prepare data for training

# %% [markdown]
# #### 2.3.1 Data preparation - No punctuation

# %%
# Tokenize the text into sequences
maxlen = 10  # Sequence length
step = 1  # Shift the window by 1 word

# Prepare training sequences
sequences = []

# Split the word into list
words = text_no_punctuation.split()

# Create sequences of maxlen words
for i in range(0, len(words) - maxlen, step):
    sequences.append([word_index_no[word] for word in words[i: i + maxlen]])

# Prepare X (inputs) and y (next word predictions)
x_no = np.array(sequences)
y_no = np.array([word_index_no[words[i + maxlen]] for i in range(0, len(words) - maxlen, step)])

# Print the prepared sequences and next words
print("Sequences (x):")
print(x_no)
print("\nNext words (y):")
print(y_no)
# Out:
# Sequences (x):
# [[ 351    5    1 ... 1098   41    1]
#  [   5    1 1571 ...   41    1  167]
#  [   1 1571 1572 ...    1  167 3070]
#  ...
#  [1573    5   15 ...  394    5    1]
#  [   5   15 1098 ...    5    1 1571]
#  [  15 1098   41 ...    1 1571 1572]]
#
# Next words (y):
# [ 167 3070    1 ... 1571 1572 1573]

# %% [markdown]
# #### 2.3.2 Data preparation - With punctuation

# %%
# Tokenize the text into sequences
maxlen = 10  # Sequence length
step = 1  # Shift the window by 1 word

# Prepare training sequences
sequences = []

# Split the word into list
words = text_with_punctuation.split()

# Create sequences of maxlen words
for i in range(0, len(words) - maxlen, step):
    # Use get to avoid KeyError for OOV words
    sequences.append([word_index_punc.get(word, 0) for word in words[i: i + maxlen]])

# Prepare X (inputs) and y (next word predictions)
x_punc = np.array(sequences)
y_punc = np.array([word_index_punc.get(words[i + maxlen], 0) for i in range(0, len(words) - maxlen, step)])

# Print the prepared sequences and next words
print("Sequences (x):")
print(x_punc)
print("\nNext words (y):")
print(y_punc)
# Out:
# Sequences (x):
# [[ 353    6    2 ... 1101   43    2]
#  [   6    2 1574 ...   43    2  169]
#  [   2 1574 1575 ...    2  169 3075]
#  ...
#  [1576    6   17 ...  396    6    2]
#  [   6   17 1101 ...    6    2 1574]
#  [  17 1101   43 ...    2 1574 1575]]
#
# Next words (y):
# [ 169 3075    2 ... 1574 1575 1576]

# %% [markdown]
# ## 3. Model trianing - No punctuation

# %% [markdown]
# ### 3.1 Optimizer selection

# %% [markdown]
# #### Adam

# %%
def model_builder_optimizer():

  # Model
  model = Sequential()
  model.add(Embedding(vocabulary_size_keras, 512))
  model.add(LSTM(512, return_sequences=True))
  model.add(LSTM(256))
  model.add(Dense(512, activation='relu'))
  model.add(Dense(256, activation='relu'))
  model.add(Dense(vocabulary_size_keras, activation='softmax'))

  # Complie
  model.compile(optimizer = Adam(learning_rate = 0.001, clipvalue=5.0),
                loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  return model

# Early stopping callback
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# Dynamic change learning rate if validation loss does not improve
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)

# %%
# Build the model
model = model_builder_optimizer()

# Train the model
model.fit(x_no, y_no, epochs=20, validation_split=0.2, callbacks=[stop_early, reduce_lr], batch_size=64)
# Out:
# Epoch 1/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.0547 - loss: 6.9399 - val_accuracy: 0.0609 - val_loss: 6.6782 - learning_rate: 0.0010
# Epoch 2/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.0599 - loss: 6.3506 - val_accuracy: 0.0623 - val_loss: 6.6761 - learning_rate: 0.0010
# Epoch 3/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.0654 - loss: 6.1168 - val_accuracy: 0.0755 - val_loss: 6.6104 - learning_rate: 0.0010
# Epoch 4/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.0783 - loss: 5.8647 - val_accuracy: 0.0795 - val_loss: 6.7123 - learning_rate: 0.0010
# Epoch 5/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.0943 - loss: 5.6509 - val_accuracy: 0.0911 - val_loss: 6.7728 - learning_rate: 0.0010
# Epoch 6/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.1040 - loss: 5.4692 - val_accuracy: 0.0798 - val_loss: 6.8583 - learning_rate: 0.0010
# Epoch 7/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.1020 - loss: 5.5705 - val_accuracy: 0.0899 - val_loss: 6.9569 - learning_rate: 5.0000e-04
# Epoch 8/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.1223 - loss: 5.2110 - val_accuracy: 0.0950 - val_loss: 7.0046 - learning_rate: 5.0000e-04

# %% [markdown]
# #### RMSprop

# %%
def model_builder_optimizer():

  # Model
  model = Sequential()
  model.add(Embedding(vocabulary_size_keras, 512))
  model.add(LSTM(512, return_sequences=True))
  model.add(LSTM(256))
  model.add(Dense(512, activation='relu'))
  model.add(Dense(256, activation='relu'))
  model.add(Dense(vocabulary_size_keras, activation='softmax'))

  # Complie
  model.compile(optimizer = RMSprop(learning_rate = 0.001, clipvalue=5.0),
                loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  return model

# Early stopping callback
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# Dynamic change learning rate if validation loss does not improve
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)

# %%
# Build the model
model = model_builder_optimizer()

# Train the model
model.fit(x_no, y_no, epochs=20, validation_split=0.2, callbacks=[stop_early, reduce_lr], batch_size=64)
# Out:
# Epoch 1/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.0556 - loss: 6.9920 - val_accuracy: 0.0609 - val_loss: 6.5935 - learning_rate: 0.0010
# Epoch 2/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.0610 - loss: 6.4823 - val_accuracy: 0.0722 - val_loss: 6.4760 - learning_rate: 0.0010
# Epoch 3/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.0662 - loss: 6.3402 - val_accuracy: 0.0776 - val_loss: 6.3524 - learning_rate: 0.0010
# Epoch 4/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.0710 - loss: 6.1466 - val_accuracy: 0.0825 - val_loss: 6.2874 - learning_rate: 0.0010
# Epoch 5/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.0835 - loss: 6.0334 - val_accuracy: 0.0858 - val_loss: 6.2987 - learning_rate: 0.0010
# Epoch 6/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.0960 - loss: 5.9280 - val_accuracy: 0.0956 - val_loss: 6.2137 - learning_rate: 0.0010
# Epoch 7/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.1080 - loss: 5.8140 - val_accuracy: 0.0991 - val_loss: 6.1844 - learning_rate: 0.0010
# Epoch 8/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.1150 - loss: 5.7113 - val_accuracy: 0.1004 - val_loss: 6.1787 - learning_rate: 0.0010
# Epoch 9/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.1245 - loss: 5.6203 - val_accuracy: 0.1040 - val_loss: 6.2058 - learning_rate: 0.0010
# Epoch 10/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.1377 - loss: 5.5385 - val_accuracy: 0.1017 - val_loss: 6.2171 - learning_rate: 0.0010
# Epoch 11/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.1425 - loss: 5.4276 - val_accuracy: 0.0951 - val_loss: 6.3144 - learning_rate: 0.0010
# Epoch 12/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.1620 - loss: 5.2022 - val_accuracy: 0.0945 - val_loss: 6.4094 - learning_rate: 5.0000e-04
# Epoch 13/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.1740 - loss: 5.0952 - val_accuracy: 0.0933 - val_loss: 6.5059 - learning_rate: 5.0000e-04

# %% [markdown]
# #### SGD

# %%
def model_builder_optimizer():

  # Model
  model = Sequential()
  model.add(Embedding(vocabulary_size_keras, 512))
  model.add(LSTM(512, return_sequences=True))
  model.add(LSTM(256))
  model.add(Dense(512, activation='relu'))
  model.add(Dense(256, activation='relu'))
  model.add(Dense(vocabulary_size_keras, activation='softmax'))

  # Complie
  model.compile(optimizer = SGD(learning_rate = 0.001, clipvalue=5.0),
                loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  return model

# Early stopping callback
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# Dynamic change learning rate if validation loss does not improve
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)

# %%
# Build the model
model = model_builder_optimizer()

# Train the model
model.fit(x_no, y_no, epochs=20, validation_split=0.2, callbacks=[stop_early, reduce_lr], batch_size=64)
# Out:
# Epoch 1/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.0472 - loss: 8.7411 - val_accuracy: 0.0609 - val_loss: 8.7366 - learning_rate: 0.0010
# Epoch 2/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.0594 - loss: 8.7352 - val_accuracy: 0.0609 - val_loss: 8.7305 - learning_rate: 0.0010
# Epoch 3/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.0587 - loss: 8.7293 - val_accuracy: 0.0609 - val_loss: 8.7243 - learning_rate: 0.0010
# Epoch 4/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.0586 - loss: 8.7232 - val_accuracy: 0.0609 - val_loss: 8.7181 - learning_rate: 0.0010
# Epoch 5/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.0598 - loss: 8.7169 - val_accuracy: 0.0609 - val_loss: 8.7118 - learning_rate: 0.0010
# Epoch 6/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.0570 - loss: 8.7112 - val_accuracy: 0.0609 - val_loss: 8.7054 - learning_rate: 0.0010
# Epoch 7/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.0581 - loss: 8.7049 - val_accuracy: 0.0609 - val_loss: 8.6990 - learning_rate: 0.0010
# Epoch 8/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.0571 - loss: 8.6985 - val_accuracy: 0.0609 - val_loss: 8.6923 - learning_rate: 0.0010
# Epoch 9/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.0564 - loss: 8.6922 - val_accuracy: 0.0609 - val_loss: 8.6855 - learning_rate: 0.0010
# Epoch 10/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.0578 - loss: 8.6848 - val_accuracy: 0.0609 - val_loss: 8.6785 - learning_rate: 0.0010
# Epoch 11/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.0576 - loss: 8.6785 - val_accuracy: 0.0609 - val_loss: 8.6711 - learning_rate: 0.0010
# Epoch 12/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.0574 - loss: 8.6710 - val_accuracy: 0.0609 - val_loss: 8.6634 - learning_rate: 0.0010
# Epoch 13/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.0570 - loss: 8.6634 - val_accuracy: 0.0609 - val_loss: 8.6551 - learning_rate: 0.0010
# Epoch 14/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.0574 - loss: 8.6544 - val_accuracy: 0.0609 - val_loss: 8.6462 - learning_rate: 0.0010
# Epoch 15/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.0562 - loss: 8.6476 - val_accuracy: 0.0609 - val_loss: 8.6364 - learning_rate: 0.0010
# Epoch 16/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.0563 - loss: 8.6371 - val_accuracy: 0.0609 - val_loss: 8.6255 - learning_rate: 0.0010
# Epoch 17/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.0584 - loss: 8.6244 - val_accuracy: 0.0609 - val_loss: 8.6129 - learning_rate: 0.0010
# Epoch 18/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.0580 - loss: 8.6127 - val_accuracy: 0.0609 - val_loss: 8.5981 - learning_rate: 0.0010
# Epoch 19/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.0575 - loss: 8.5965 - val_accuracy: 0.0609 - val_loss: 8.5801 - learning_rate: 0.0010
# Epoch 20/20
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.0567 - loss: 8.5789 - val_accuracy: 0.0609 - val_loss: 8.5571 - learning_rate: 0.0010

# %% [markdown]
# #### **Discussion**
#
# The results indicate that the Adam optimizer leads to overfitting after a few epochs, while SGD struggles to improve accuracy. Therefore, RMSprop is chosen as the optimizer, as it provides a better balance and improves validation accuracy.

# %% [markdown]
# ### 3.2 LSTM model

# %% [markdown]
# #### Hyperparameter tuning

# %%
def build_model_tuning(hp):
    model = Sequential()

    # Choose an optimal embedding dimension between 64 and 256
    embed_dim = hp.Int('embedding_dim', min_value=64, max_value=256, step=32)
    model.add(Embedding(input_dim=vocabulary_size_keras, output_dim=embed_dim))

    # Choose an optimal number of LSTM units between 64 and 512
    lstm_units = hp.Int('lstm_units', min_value=64, max_value=512, step=64)
    model.add(LSTM(units=lstm_units, return_sequences=True))

    # Choose an optimal number of LSTM units between 64 and 512
    lstm_units2 = hp.Int('lstm_units2', min_value=64, max_value=512, step=64)
    model.add(LSTM(units=lstm_units2))

    # Dense layers
    model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(vocabulary_size_keras, activation='softmax'))

    model.compile(optimizer=RMSprop(learning_rate=0.001, clipvalue=5.0),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# Early stopping callback
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner = kt.Hyperband(build_model_tuning, objective='val_accuracy',
                     max_epochs=20, factor=3, directory=f'/content/',
                     project_name=f'lstm')

tuner.search(x_no, y_no, epochs=20, validation_split=0.2, callbacks=[stop_early])

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best hyperparameters for LSTM: {best_hps.values}")

best_model = tuner.get_best_models(num_models=1)[0]
val_loss, val_acc = best_model.evaluate(x_no, y_no, verbose=0)
print(f"Validation accuracy for LSTM: {val_acc:.4f}\n")
# Out:
# Trial 30 Complete [00h 02m 20s]
# val_accuracy: 0.1030014306306839
#
# Best val_accuracy So Far: 0.10404954850673676
# Total elapsed time: 00h 33m 50s
# Best hyperparameters for LSTM: {'embedding_dim': 192, 'lstm_units': 448, 'lstm_units2': 384, 'tuner/epochs': 20, 'tuner/initial_epoch': 7, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0012'}
# Validation accuracy for LSTM: 0.1379

# %% [markdown]
# #### Trian model

# %%
def model_builder():

  # Model
  model = Sequential()
  model.add(Embedding(vocabulary_size_keras, 192))
  model.add(LSTM(448, return_sequences=True))
  model.add(LSTM(384))
  model.add(Dense(512, activation='relu'))
  model.add(Dense(256, activation='relu'))
  model.add(Dense(vocabulary_size_keras, activation='softmax'))

  # Complie
  model.compile(optimizer = RMSprop(learning_rate = 0.001, clipvalue=5.0),
                loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9514 - loss: 0.2249 - val_accuracy: 0.0356 - val_loss: 32.9269
# Epoch 93/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9515 - loss: 0.2288 - val_accuracy: 0.0400 - val_loss: 33.6661
# Epoch 94/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9503 - loss: 0.2398 - val_accuracy: 0.0330 - val_loss: 33.4851
# Epoch 95/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9511 - loss: 0.2352 - val_accuracy: 0.0394 - val_loss: 33.8045
# Epoch 96/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9515 - loss: 0.2299 - val_accuracy: 0.0341 - val_loss: 34.1759
# Epoch 97/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9517 - loss: 0.2273 - val_accuracy: 0.0362 - val_loss: 34.8275
# Epoch 98/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9511 - loss: 0.2339 - val_accuracy: 0.0417 - val_loss: 34.0400
# Epoch 99/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9511 - loss: 0.2477 - val_accuracy: 0.0393 - val_loss: 32.7558
# Epoch 100/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9499 - loss: 0.2509 - val_accuracy: 0.0427 - val_loss: 33.3159

# %% [markdown]
# #### Evaluation

# %%
# Load model
model = load_model("/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/task3_lstm_nopunc_model.keras")
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 10, 192)             │       1,202,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 10, 448)             │       1,148,672 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 384)                 │       1,279,488 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 512)                 │         197,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 6264)                │       1,609,848 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,138,290 (42.49 MB)
#  Trainable params: 5,569,144 (21.24 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,569,146 (21.24 MB)

# %%
# Load the tokenizer using pickle
with open('/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/tokenizer_no_punctuation.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
def generate_text(model, tokenizer, input_text, num_gen_words):

    output_text = []
    for i in range(num_gen_words):

        # Predict word
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        pad_encoded = pad_sequences([encoded_text], maxlen=10, truncating='pre')
        prob_index = model.predict(pad_encoded, verbose=0)[0]

        # Map highest probability index with word
        highest_prob_index = np.argmax(prob_index)
        pred_word = tokenizer.index_word.get(highest_prob_index, '')

        # Update the input text for the next prediction
        input_text = input_text + ' ' + pred_word

        # Output text
        output_text.append(pred_word)

    return " ".join(output_text)

# %%
# Seed text:
'''Original: After a short interval, the American film star was ushered in, and we rose to our feet.'''

seed_text = "After a short interval, the American film star was ushered "
num_gen_words = 10
generated_text = generate_text(model, tokenizer, seed_text, num_gen_words=num_gen_words)
print(generated_text)
# Out:
# in and we rose and our eyes minor on a

# %% [markdown]
# ### 3.3 GRU model

# %% [markdown]
# #### Hyperparameter tuning

# %%
def build_model_tuning(hp):
    model = Sequential()

    # Choose an optimal embedding dimension between 64 and 512
    embed_dim = hp.Int('embedding_dim', min_value=64, max_value=512, step=32)
    model.add(Embedding(input_dim=vocabulary_size_keras, output_dim=embed_dim))

    # Choose an optimal number of GRU units between 64 and 512
    gru_units = hp.Int('gru_units', min_value=64, max_value=512, step=64)
    model.add(GRU(units=gru_units, return_sequences=True))

    # Choose an optimal number of GRU units between 128 and 512
    gru_units2 = hp.Int('gru_units2', min_value=64, max_value=512, step=64)
    model.add(GRU(units=gru_units2))

    # Dense layers
    model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(vocabulary_size_keras, activation='softmax'))

    model.compile(optimizer=RMSprop(learning_rate=0.001, clipvalue=5.0),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# Early stopping callback
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner = kt.Hyperband(build_model_tuning, objective='val_accuracy',
                     max_epochs=20, factor=3, directory=f'/content/',
                     project_name=f'gru')

tuner.search(x_no, y_no, epochs=20, validation_split=0.2, callbacks=[stop_early])

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best hyperparameters for GRU: {best_hps.values}")

best_model = tuner.get_best_models(num_models=1)[0]
val_loss, val_acc = best_model.evaluate(x_no, y_no, verbose=0)
print(f"Validation accuracy for GRU: {val_acc:.4f}\n")
# Out:
# Trial 30 Complete [00h 01m 45s]
# val_accuracy: 0.10557408630847931
#
# Best val_accuracy So Far: 0.10805145651102066
# Total elapsed time: 00h 30m 20s
# Best hyperparameters for GRU: {'embedding_dim': 256, 'gru_units': 128, 'gru_units2': 256, 'tuner/epochs': 7, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
# Validation accuracy for GRU: 0.1284

# %% [markdown]
# #### Trian model

# %%
def model_builder():

  # Model
  model = Sequential()
  model.add(Embedding(vocabulary_size_keras, 256))
  model.add(GRU(128, return_sequences=True))
  model.add(GRU(256))
  model.add(Dense(512, activation='relu'))
  model.add(Dense(256, activation='relu'))
  model.add(Dense(vocabulary_size_keras, activation='softmax'))

  # Complie
  model.compile(optimizer = RMSprop(learning_rate = 0.001, clipvalue=5.0),
                loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
# Build the model using best hyperparameters
model = model_builder()

# Train and Save model
checkpoint = ModelCheckpoint("/content/task3_gru_nopunc_model.keras", save_best_only=True, monitor="loss", mode="min")
history = model.fit(x_no, y_no, epochs=100, validation_split=0.1, callbacks=[checkpoint], batch_size=64)
# Out:
# Epoch 1/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0565 - loss: 6.9672 - val_accuracy: 0.0758 - val_loss: 6.4481
# Epoch 2/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.0746 - loss: 6.2958 - val_accuracy: 0.0932 - val_loss: 6.2500
# Epoch 3/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.0958 - loss: 5.9987 - val_accuracy: 0.0985 - val_loss: 6.2034
# Epoch 4/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.1114 - loss: 5.8530 - val_accuracy: 0.1010 - val_loss: 6.2595
# Epoch 5/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.1213 - loss: 5.7135 - val_accuracy: 0.1056 - val_loss: 6.1868
# Epoch 6/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.1349 - loss: 5.5775 - val_accuracy: 0.1088 - val_loss: 6.1817
# Epoch 7/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.1441 - loss: 5.4592 - val_accuracy: 0.1061 - val_loss: 6.3096
# Epoch 8/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.1551 - loss: 5.3488 - val_accuracy: 0.1082 - val_loss: 6.3686
# Epoch 9/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.1693 - loss: 5.2233 - val_accuracy: 0.1014 - val_loss: 6.5025
# Epoch 10/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.1866 - loss: 5.1000 - val_accuracy: 0.0953 - val_loss: 6.6784
# Epoch 11/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.1991 - loss: 4.9772 - val_accuracy: 0.0945 - val_loss: 6.7277
# Epoch 12/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.2183 - loss: 4.8552 - val_accuracy: 0.0877 - val_loss: 6.9993
# Epoch 13/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.2354 - loss: 4.6880 - val_accuracy: 0.0793 - val_loss: 7.2227
# Epoch 14/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.2577 - loss: 4.5559 - val_accuracy: 0.0810 - val_loss: 7.3461
# Epoch 15/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.2733 - loss: 4.4393 - val_accuracy: 0.0776 - val_loss: 7.8028
# Epoch 16/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.2970 - loss: 4.2803 - val_accuracy: 0.0696 - val_loss: 7.9902
# Epoch 17/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3139 - loss: 4.1526 - val_accuracy: 0.0682 - val_loss: 8.3850
# Epoch 18/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3391 - loss: 3.9871 - val_accuracy: 0.0665 - val_loss: 8.6101
# Epoch 19/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3583 - loss: 3.8633 - val_accuracy: 0.0652 - val_loss: 9.1269
# Epoch 20/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3827 - loss: 3.7117 - val_accuracy: 0.0589 - val_loss: 9.7761
# Epoch 21/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4028 - loss: 3.5627 - val_accuracy: 0.0528 - val_loss: 9.9432
# Epoch 22/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4269 - loss: 3.4237 - val_accuracy: 0.0606 - val_loss: 10.4867
# Epoch 23/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.
100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9309 - loss: 0.3353 - val_accuracy: 0.0337 - val_loss: 34.0799
# Epoch 87/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9296 - loss: 0.3474 - val_accuracy: 0.0372 - val_loss: 34.5215
# Epoch 88/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9331 - loss: 0.3214 - val_accuracy: 0.0387 - val_loss: 35.3178
# Epoch 89/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9358 - loss: 0.3315 - val_accuracy: 0.0366 - val_loss: 34.4102
# Epoch 90/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9348 - loss: 0.3282 - val_accuracy: 0.0364 - val_loss: 35.1640
# Epoch 91/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9373 - loss: 0.3080 - val_accuracy: 0.0402 - val_loss: 35.9249
# Epoch 92/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9370 - loss: 0.3173 - val_accuracy: 0.0360 - val_loss: 34.5740
# Epoch 93/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9383 - loss: 0.2983 - val_accuracy: 0.0373 - val_loss: 34.1900
# Epoch 94/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9362 - loss: 0.3174 - val_accuracy: 0.0343 - val_loss: 35.8167
# Epoch 95/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9375 - loss: 0.3212 - val_accuracy: 0.0358 - val_loss: 35.4958
# Epoch 96/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9399 - loss: 0.3062 - val_accuracy: 0.0358 - val_loss: 35.9939
# Epoch 97/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9406 - loss: 0.2911 - val_accuracy: 0.0387 - val_loss: 36.6628
# Epoch 98/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9433 - loss: 0.2830 - val_accuracy: 0.0375 - val_loss: 36.3692
# Epoch 99/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9454 - loss: 0.2885 - val_accuracy: 0.0402 - val_loss: 36.8164
# Epoch 100/100
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9434 - loss: 0.2813 - val_accuracy: 0.0351 - val_loss: 36.4419

# %% [markdown]
# #### Evaluation

# %%
# Load model
model = load_model("/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/task3_gru_nopunc_model.keras")
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ (None, 10, 256)             │       1,603,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_4 (GRU)                          │ (None, 10, 128)             │         148,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_5 (GRU)                          │ (None, 256)                 │         296,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 6264)                │       1,609,848 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,842,034 (29.91 MB)
#  Trainable params: 3,921,016 (14.96 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,921,018 (14.96 MB)

# %%
# Load the tokenizer using pickle
with open('/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/tokenizer_no_punctuation.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
def generate_text(model, tokenizer, input_text, num_gen_words):

    output_text = []
    for i in range(num_gen_words):

        # Predict word
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        pad_encoded = pad_sequences([encoded_text], maxlen=10, truncating='pre')
        prob_index = model.predict(pad_encoded, verbose=0)[0]

        # Map highest probability index with word
        highest_prob_index = np.argmax(prob_index)
        pred_word = tokenizer.index_word.get(highest_prob_index, '')

        # Update the input text for the next prediction
        input_text = input_text + ' ' + pred_word

        # Output text
        output_text.append(pred_word)

    return " ".join(output_text)

# %%
# Seed text:
'''Original: After a short interval, the American film star was ushered in, and we rose to our feet.'''

seed_text = "After a short interval, the American film star was ushered"
num_gen_words = 10
generated_text = generate_text(model, tokenizer, seed_text, num_gen_words=num_gen_words)
print(generated_text)
# Out:
# coming from limited he channel the city of whispered landlady

# %% [markdown]
# ## 4. Model trianing - With punctuation

# %% [markdown]
# ### 4.1 GRU model

# %% [markdown]
# #### Hyperparameter tuning

# %%
def build_model_tuning(hp):
    model = Sequential()

    # Choose an optimal embedding dimension between 64 and 512
    embed_dim = hp.Int('embedding_dim', min_value=64, max_value=512, step=32)
    model.add(Embedding(input_dim=vocabulary_size_punc, output_dim=embed_dim))

    # Choose an optimal number of GRU units between 64 and 512
    gru_units = hp.Int('gru_units', min_value=64, max_value=512, step=64)
    model.add(GRU(units=gru_units, return_sequences=True))

    # Choose an optimal number of GRU units between 128 and 512
    gru_units2 = hp.Int('gru_units2', min_value=64, max_value=512, step=64)
    model.add(GRU(units=gru_units2))

    # Dense layers
    model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(vocabulary_size_punc, activation='softmax'))

    model.compile(optimizer=RMSprop(learning_rate=0.001, clipvalue=5.0),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# Early stopping callback
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner = kt.Hyperband(build_model_tuning, objective='val_accuracy',
                     max_epochs=20, factor=3, directory=f'/content/',
                     project_name=f'gru_punc')

tuner.search(x_punc, y_punc, epochs=20, validation_split=0.2, callbacks=[stop_early])

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best hyperparameters for GRU (with punctuation): {best_hps.values}")

best_model = tuner.get_best_models(num_models=1)[0]
val_loss, val_acc = best_model.evaluate(x_punc, y_punc, verbose=0)
print(f"Validation accuracy for GRU (with punctuation): {val_acc:.4f}\n")
# Out:
# Trial 30 Complete [00h 01m 54s]
# val_accuracy: 0.14254538714885712
#
# Best val_accuracy So Far: 0.1469099223613739
# Total elapsed time: 00h 32m 24s
# Best hyperparameters for GRU (with punctuation): {'embedding_dim': 512, 'gru_units': 256, 'gru_units2': 448, 'tuner/epochs': 7, 'tuner/initial_epoch': 3, 'tuner/bracket': 2, 'tuner/round': 1, 'tuner/trial_id': '0000'}
# Validation accuracy for GRU (with punctuation): 0.1743

# %% [markdown]
# #### Trian model

# %%
def model_builder():

  # Model
  model = Sequential()
  model.add(Embedding(vocabulary_size_punc, 512))
  model.add(GRU(256, return_sequences=True))
  model.add(GRU(448))
  model.add(Dense(512, activation='relu'))
  model.add(Dense(256, activation='relu'))
  model.add(Dense(vocabulary_size_punc, activation='softmax'))

  # Complie
  model.compile(optimizer = RMSprop(learning_rate = 0.001, clipvalue=5.0),
                loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
# Build the model using best hyperparameters
model = model_builder()

# Train and Save model
checkpoint = ModelCheckpoint("/content/task3_gru_withpunc_model.keras",
                             save_best_only=True, monitor="loss", mode="min")
history = model.fit(x_punc, y_punc, epochs=100, validation_split=0.1, callbacks=[checkpoint], batch_size=64)
# Out:
# Epoch 1/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.0715 - loss: 6.7084 - val_accuracy: 0.1121 - val_loss: 6.1211
# Epoch 2/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.1117 - loss: 5.9316 - val_accuracy: 0.1285 - val_loss: 5.9789
# Epoch 3/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.1378 - loss: 5.6609 - val_accuracy: 0.1273 - val_loss: 5.9147
# Epoch 4/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.1562 - loss: 5.4825 - val_accuracy: 0.1391 - val_loss: 5.9572
# Epoch 5/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.1737 - loss: 5.3271 - val_accuracy: 0.1358 - val_loss: 5.9429
# Epoch 6/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.1814 - loss: 5.2503 - val_accuracy: 0.1397 - val_loss: 5.9788
# Epoch 7/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.1936 - loss: 5.1365 - val_accuracy: 0.1412 - val_loss: 6.0264
# Epoch 8/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.2127 - loss: 4.9794 - val_accuracy: 0.1330 - val_loss: 6.1103
# Epoch 9/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.2244 - loss: 4.8656 - val_accuracy: 0.1327 - val_loss: 6.4942
# Epoch 10/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.2446 - loss: 4.7346 - val_accuracy: 0.1184 - val_loss: 6.5729
# Epoch 11/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.2603 - loss: 4.6019 - val_accuracy: 0.1133 - val_loss: 6.6140
# Epoch 12/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.2766 - loss: 4.4692 - val_accuracy: 0.1180 - val_loss: 6.8153
# Epoch 13/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.3016 - loss: 4.2753 - val_accuracy: 0.0964 - val_loss: 7.1648
# Epoch 14/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.
100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9164 - loss: 0.4469 - val_accuracy: 0.0625 - val_loss: 28.5479
# Epoch 78/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9201 - loss: 0.4122 - val_accuracy: 0.0543 - val_loss: 29.1534
# Epoch 79/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9181 - loss: 0.4255 - val_accuracy: 0.0532 - val_loss: 30.1723
# Epoch 80/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9196 - loss: 0.4284 - val_accuracy: 0.0522 - val_loss: 29.1205
# Epoch 81/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9192 - loss: 0.4135 - val_accuracy: 0.0505 - val_loss: 29.1829
# Epoch 82/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9233 - loss: 0.4008 - val_accuracy: 0.0569 - val_loss: 29.2328
# Epoch 83/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9245 - loss: 0.3864 - val_accuracy: 0.0573 - val_loss: 29.1305
# Epoch 84/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9215 - loss: 0.4204 - val_accuracy: 0.0583 - val_loss: 29.8673
# Epoch 85/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9205 - loss: 0.4281 - val_accuracy: 0.0630 - val_loss: 29.5751
# Epoch 86/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9225 - loss: 0.4035 - val_accuracy: 0.0525 - val_loss: 28.7249
# Epoch 87/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9219 - loss: 0.4301 - val_accuracy: 0.0601 - val_loss: 29.6107
# Epoch 88/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9256 - loss: 0.3973 - val_accuracy: 0.0574 - val_loss: 29.6119
# Epoch 89/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9197 - loss: 0.4193 - val_accuracy: 0.0513 - val_loss: 30.0079
# Epoch 90/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9253 - loss: 0.3883 - val_accuracy: 0.0525 - val_loss: 30.6465
# Epoch 91/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9243 - loss: 0.3993 - val_accuracy: 0.0494 - val_loss: 29.8211
# Epoch 92/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9223 - loss: 0.4093 - val_accuracy: 0.0482 - val_loss: 31.1017
# Epoch 93/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9232 - loss: 0.3933 - val_accuracy: 0.0592 - val_loss: 30.6001
# Epoch 94/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9275 - loss: 0.3941 - val_accuracy: 0.0513 - val_loss: 30.6305
# Epoch 95/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9288 - loss: 0.3733 - val_accuracy: 0.0505 - val_loss: 30.5490
# Epoch 96/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9245 - loss: 0.3953 - val_accuracy: 0.0543 - val_loss: 29.9944
# Epoch 97/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9252 - loss: 0.3970 - val_accuracy: 0.0590 - val_loss: 29.9117
# Epoch 98/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9256 - loss: 0.4033 - val_accuracy: 0.0552 - val_loss: 31.3159
# Epoch 99/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9282 - loss: 0.3887 - val_accuracy: 0.0515 - val_loss: 30.0562
# Epoch 100/100
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9245 - loss: 0.4116 - val_accuracy: 0.0642 - val_loss: 32.1224

# %% [markdown]
# #### Evaluation

# %%
# Load model
model = load_model("/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/task3_gru_withpunc_model.keras")
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 10, 512)             │       3,211,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 10, 256)             │         591,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_3 (GRU)                          │ (None, 448)                 │         948,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 512)                 │         229,888 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 6272)                │       1,611,904 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,449,218 (51.30 MB)
#  Trainable params: 6,724,608 (25.65 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 6,724,610 (25.65 MB)

# %%
# Load the tokenizer using pickle
with open('/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/tokenizer_with_punctuation.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
def generate_text(model, tokenizer, input_text, num_gen_words):

    output_text = []
    for i in range(num_gen_words):

        # Predict word
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        pad_encoded = pad_sequences([encoded_text], maxlen=10, truncating='pre')
        prob_index = model.predict(pad_encoded, verbose=0)[0]

        # Map highest probability index with word
        highest_prob_index = np.argmax(prob_index)
        pred_word = tokenizer.index_word.get(highest_prob_index, '')

        # Update the input text for the next prediction
        input_text = input_text + ' ' + pred_word

        # Output text
        output_text.append(pred_word)

    return " ".join(output_text)

# %%
# Seed text:
'''Original: After a short interval, the American film star was ushered in, and we rose to our feet.'''

seed_text = "After a short interval, the American film star was "
num_gen_words = 10
generated_text = generate_text(model, tokenizer, seed_text, num_gen_words=num_gen_words)
print(generated_text)
# Out:
# doubtless six itself . from too in vain we are

# %% [markdown]
# ## 5. Comparison with ChatGPT

# %% [markdown]
# Text generator

# %%
def generate_text(model, tokenizer, input_text, num_gen_words):

    output_text = []
    for i in range(num_gen_words):

        # Predict word
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        pad_encoded = pad_sequences([encoded_text], maxlen=10, truncating='pre')
        prob_index = model.predict(pad_encoded, verbose=0)[0]

        # Map highest probability index with word
        highest_prob_index = np.argmax(prob_index)
        pred_word = tokenizer.index_word.get(highest_prob_index, '')

        # Update the input text for the next prediction
        input_text = input_text + ' ' + pred_word

        # Output text
        output_text.append(pred_word)

    return " ".join(output_text)

# %% [markdown]
# **Original text**
#
# At Bertram’s Hotel by Agatha Christie
# - During the war, houses were demolished on the right of it, and a little farther down on the left of it, but Bertram’s itself remained unscathed.
# - Naturally it could not escape being, as house agents would say, scratched, bruised and marked, but by the expenditure of only a reasonable amount of money it was restored to its original condition.

# %% [markdown]
# #### **5.1 LSTM model**

# %%
# Load model
model_lstm = load_model("/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/task3_lstm_nopunc_model.keras")
# Load the tokenizer using pickle
with open('/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/tokenizer_no_punctuation.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
# Seed text and references
seed_text = "During the war, houses were demolished on the right of it, and"
reference = "a little farther down on the left of it, but"

# Generating word
num_gen_words = 10
generated_text = generate_text(model_lstm, tokenizer, seed_text, num_gen_words=num_gen_words)
print("Predicted word: ", generated_text)

# Create a ROUGE scorer (using 'rouge1', 'rouge2', and 'rougeL')
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, generated_text)

# Print the scores
print("\nROUGE Scores:")
scores
# Out:
# Predicted word:  omurphy got down the steps of him on a kind
#
# ROUGE Scores:
# {'rouge1': Score(precision=0.5, recall=0.5, fmeasure=0.5),
#  'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rougeL': Score(precision=0.3, recall=0.3, fmeasure=0.3)}

# %%
# Seed text and references
seed_text = "Naturally it could not escape being, as house agents would say,"
reference = "scratched, bruised and marked, but by the expenditure of only"

# Generating word
num_gen_words = 10
generated_text = generate_text(model_lstm, tokenizer, seed_text, num_gen_words=num_gen_words)
print("Predicted word: ", generated_text)

# Create a ROUGE scorer (using 'rouge1', 'rouge2', and 'rougeL')
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, generated_text)

# Print the scores
print("\nROUGE Scores:")
scores
# Out:
# Predicted word:  i understand that he had a man having gone at
#
# ROUGE Scores:
# {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)}

# %% [markdown]
# #### **5.2 GRU model - no punctuation**

# %%
# Load model
model_gru = load_model("/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/task3_gru_nopunc_model.keras")
# Load the tokenizer using pickle
with open('/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/tokenizer_no_punctuation.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
# Seed text and references
seed_text = "During the war, houses were demolished on the right of it, and"
reference = "a little farther down on the left of it, but"

# Generating word
num_gen_words = 10
generated_text = generate_text(model_gru, tokenizer, seed_text, num_gen_words=num_gen_words)
print("Predicted word: ", generated_text)

# Create a ROUGE scorer (using 'rouge1', 'rouge2', and 'rougeL')
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, generated_text)

# Print the scores
print("\nROUGE Scores:")
scores
# Out:
# Predicted word:  hidden somewhere by poirot shook his head no less one
#
# ROUGE Scores:
# {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)}

# %%
# Seed text and references
seed_text = "Naturally it could not escape being, as house agents would say,"
reference = "scratched, bruised and marked, but by the expenditure of only"

# Generating word
num_gen_words = 10
generated_text = generate_text(model_gru, tokenizer, seed_text, num_gen_words=num_gen_words)
print("Predicted word: ", generated_text)

# Create a ROUGE scorer (using 'rouge1', 'rouge2', and 'rougeL')
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, generated_text)

# Print the scores
print("\nROUGE Scores:")
scores
# Out:
# Predicted word:  the doctor looked alone oh poirot seemed there said the
#
# ROUGE Scores:
# {'rouge1': Score(precision=0.1, recall=0.1, fmeasure=0.10000000000000002),
#  'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rougeL': Score(precision=0.1, recall=0.1, fmeasure=0.10000000000000002)}

# %% [markdown]
# #### **5.3 GRU model - with punctuation**

# %%
# Load model
model_gru_punc = load_model("/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/task3_gru_withpunc_model.keras")
# Load the tokenizer using pickle
with open('/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/tokenizer_no_punctuation.pkl', 'rb') as f:
    tokenizer_punc = pickle.load(f)

# %%
# Seed text and references
seed_text = "During the war, houses were demolished on the right of it, and"
reference = "a little farther down on the left of it, but"

# Generating word
num_gen_words = 10
generated_text = generate_text(model_gru_punc, tokenizer_punc, seed_text, num_gen_words=num_gen_words)
print("Predicted word: ", generated_text)

# Create a ROUGE scorer (using 'rouge1', 'rouge2', and 'rougeL')
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, generated_text)

# Print the scores
print("\nROUGE Scores:")
scores
# Out:
# Predicted word:  i deal it time is them only nothing left the
#
# ROUGE Scores:
# {'rouge1': Score(precision=0.3, recall=0.3, fmeasure=0.3),
#  'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rougeL': Score(precision=0.1, recall=0.1, fmeasure=0.10000000000000002)}

# %%
# Seed text and references
seed_text = "Naturally it could not escape being, as house agents would say,"
reference = "scratched, bruised and marked, but by the expenditure of only"

# Generating word
num_gen_words = 10
generated_text = generate_text(model_gru_punc, tokenizer_punc, seed_text, num_gen_words=num_gen_words)
print("Predicted word: ", generated_text)

# Create a ROUGE scorer (using 'rouge1', 'rouge2', and 'rougeL')
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, generated_text)

# Print the scores
print("\nROUGE Scores:")
scores
# Out:
# Predicted word:  doubtless the out poirot star have is traitor big poirot
#
# ROUGE Scores:
# {'rouge1': Score(precision=0.1, recall=0.1, fmeasure=0.10000000000000002),
#  'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rougeL': Score(precision=0.1, recall=0.1, fmeasure=0.10000000000000002)}

# %% [markdown]
# #### **5.4 ChatGPT result**

# %% [markdown]
# ***Prompt: Please predict next 10 words***
#
# 1) **Seed text**: During the war, houses were demolished on the right of it, and
#
# Result: new buildings were constructed to replace the damaged structures, while others
#
# 2) **Seed text**: Naturally it could not escape being, as house agents would say,
#
# **Result**: a desirable residence with a rich historical background and unique charm.

# %%
# Seed text and references
seed_text = "During the war, houses were demolished on the right of it, and"
reference = "a little farther down on the left of it, but"

# Generating word
generate_text = "new buildings were constructed to replace the damaged structures, while others"

# Create a ROUGE scorer (using 'rouge1', 'rouge2', and 'rougeL')
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, generated_text)

# Print the scores
print("\nROUGE Scores:")
scores
# Out:
# ROUGE Scores:
# {'rouge1': Score(precision=0.2, recall=0.2, fmeasure=0.20000000000000004),
#  'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rougeL': Score(precision=0.1, recall=0.1, fmeasure=0.10000000000000002)}

# %%
# Seed text and references
seed_text = "Naturally it could not escape being, as house agents would say,"
reference = "scratched, bruised and marked, but by the expenditure of only"

# Generating word
generate_text = "a desirable residence with a rich historical background and unique charm."

# Create a ROUGE scorer (using 'rouge1', 'rouge2', and 'rougeL')
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, generated_text)

# Print the scores
print("\nROUGE Scores:")
scores
# Out:
# ROUGE Scores:
# {'rouge1': Score(precision=0.15789473684210525, recall=0.3, fmeasure=0.20689655172413793),
#  'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rougeL': Score(precision=0.15789473684210525, recall=0.3, fmeasure=0.20689655172413793)}

# %% [markdown]
# ***Prompt: Please predict next 10 words and write in Agatha Christie way***
#
# 1) **Seed text:** During the war, houses were demolished on the right of it, and
#
# **Result:** the remnants stood solemnly, whispering echoes of lives once lived.
#
# 2) **Seed text:** Naturally it could not escape being, as house agents would say,
#
# **Result:** “a residence of character, with an air of quiet dignity.”

# %%
# Seed text and references
seed_text = "During the war, houses were demolished on the right of it, and"
reference = "a little farther down on the left of it, but"

# Generating word
generate_text = "the remnants stood solemnly, whispering echoes of lives once lived."

# Create a ROUGE scorer (using 'rouge1', 'rouge2', and 'rougeL')
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, generated_text)

# Print the scores
print("\nROUGE Scores:")
scores
# Out:
# ROUGE Scores:
# {'rouge1': Score(precision=0.2, recall=0.2, fmeasure=0.20000000000000004),
#  'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rougeL': Score(precision=0.1, recall=0.1, fmeasure=0.10000000000000002)}

# %%
# Seed text and references
seed_text = "Naturally it could not escape being, as house agents would say,"
reference = "scratched, bruised and marked, but by the expenditure of only"

# Generating word
generate_text = "a residence of character, with an air of quiet dignity."

# Create a ROUGE scorer (using 'rouge1', 'rouge2', and 'rougeL')
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, generated_text)

# Print the scores
print("\nROUGE Scores:")
scores
# Out:
# ROUGE Scores:
# {'rouge1': Score(precision=0.1, recall=0.1, fmeasure=0.10000000000000002),
#  'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#  'rougeL': Score(precision=0.1, recall=0.1, fmeasure=0.10000000000000002)}

# %% [markdown]
# #### **Discussion**
#
# - The ROUGE score is used to evaluate the quality of generated text by measuring its similarity to the reference text.
# - LSTM and GRU models that train with text that remove punctuation show inconsistency in their ROUGE scores, while ChatGPT demonstrates more stability in its results.
# - This inconsistency in LSTM and GRU, which are RNN-based models, comes from their difficulty in capturing long-term dependencies, leading to fluctuating ROUGE scores.
# - In contrast, ChatGPT performs more consistently due to the transformer architecture, which handles longer-range context more effectively.
# - Additionally, training the model with punctuation provides clearer segmentation, which slightly improves text coherence and ROUGE scores. However,using more complex tokenization might help by allowing the model to better handle rare words, subwords, and punctuation, which could lead to more consistent and accurate text generation.
# - The difference prompt to ChatGPT will provide the different generated text result. The initial prompt yielded general information, while the second prompt requesting an Agatha Christie style produced a literary response. This shows that ChatGPT has learned from lots of different kinds of writing.
# - Therefore, providing more training data, especially data with different styles and types of writing could help the model better recognize text patterns and successfully generate text that is closer to human-level sentences

# %% [markdown]
# ## 6.  Report

# %% [markdown]
# **Types of Approach**
#
# 1) Data Preprocessing
#   - Text cleaning
#     - This experiment compares two preprocessing approaches including removing all punctuation and retaining some punctuation in the text
#     - The results indicate that training with punctuation leads to more consistent ROUGE scores, suggesting that punctuation provides useful structural information for the model
#   - Tokenization
#     - This report uses only the Keras tokenizer for model training because applying Spacy tokenization resulted in a significant number of out-of-vocabulary (OOV) words, leading to blank or missing predicted words.
#     - Therefore, increasing the vocabulary size or using subword tokenization may be considered in the future to improve text generation accuracy.
#
# 2) Model selection
#   - LSTM (Long Short-Term Memory)
#     - The result shows instability in ROUGE scores when trained on text without punctuation
#   - GRU (Gated Recurrent Unit)
#     - The ROUGE scores are slightly improve when trained on text with punctuation
#   - Transformer-based models
#     - The result shows that ROUGE scores from ChatGPT is more consistancy compared to RNN-based model
#     - Therefore, this type of model could improve the performance of text generator since its ability to handle long-range context
#
# ---
#
# **Performance Improvement Techniques (Ordered from Most to Least Impactful)**
#
# 1) **Using Transformer-based Models**
#    - Trasformer-based models like ChatGPT shows better performance in in text generation by effectively handling long-range dependencies
#
# 2) **Advance Tokenization**
#    - Using subword tokenization could solve the out-of-vocabulary (OOV) issue, allowing the model to handle rare words more effictively.
#    - Advanced tokenization also improves punctuation handling, leading to better sentence structure and coherence.
#
# 3) **Training with Punctuation**
#    - The experiment shows that models trained with punctuation exhibit more stable ROUGE scores compared to those trained on text with all punctuation removed
#    - Therefore, including punctuation in training data with the better tokenization method could improve the performance of model
#
# 4) **Increasing training text**
#    - Expanding the training dataset could help the model's performance, reducing overfitting and improving the quality of generated text

# %% [markdown]
# ## 7. Demo session

# %% [markdown]
# Install library

# %% [markdown]
# Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Load and preprocess the text
with open("/content/drive/MyDrive/Coursework_chatwipa/TASK 3/61262-0.txt", 'r', encoding='utf-8') as file:
    text = file.read().lower()

# %%
# !pip install -q -U keras-tuner
# !pip install rouge-score
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (4.67.1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, GRU, LayerNormalization, BatchNormalization
import keras_tuner as kt
import re
from keras.optimizers import Adam, RMSprop, SGD
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import pickle
import spacy
from rouge_score import rouge_scorer

# %% [markdown]
# #### 7.1 Predict text

# %%
# Load model
model = load_model("/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/task3_gru_withpunc_model.keras")

# Load the tokenizer using pickle
with open('/content/drive/MyDrive/Coursework_chatwipa/TASK 3/Model/tokenizer_with_punctuation.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Text generator function
def generate_text(model, tokenizer, input_text, num_gen_words):

    output_text = []
    for i in range(num_gen_words):

        # Predict word
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        pad_encoded = pad_sequences([encoded_text], maxlen=10, truncating='pre')
        prob_index = model.predict(pad_encoded, verbose=0)[0]

        # Map highest probability index with word
        highest_prob_index = np.argmax(prob_index)
        pred_word = tokenizer.index_word.get(highest_prob_index, '')

        # Update the input text for the next prediction
        input_text = input_text + ' ' + pred_word

        # Output text
        output_text.append(pred_word)

    return " ".join(output_text)

# %%
# Text
seed_text = "Once upon a midnight dreary, I was seeing the"

# Number of word to generate
num_gen_words = 20

# Generate text
generated_text = generate_text(model, tokenizer, seed_text, num_gen_words)
print(generated_text)
# Out:
# stared in a ivy and you see the fashionable frenchman that a uncommon point of mr . vavasour who is

# %% [markdown]
# #### 7.2 Training one epoch

# %% [markdown]
# Clean all punctuation

# %%
# Remove Gutenberg header and footer (if present)
text_no_punctuation = re.sub(r"\*\*\* START OF THE PROJECT GUTENBERG EBOOK.*?\*\*\*", "", text, flags=re.DOTALL)
text_no_punctuation = re.sub(r"\*\*\* END OF THE PROJECT GUTENBERG EBOOK.*?\*\*\*", "", text_no_punctuation, flags=re.DOTALL)

# Remove excessive newlines
text_no_punctuation = re.sub(r"\n{2,}", " ", text_no_punctuation).strip()
# Remove non-alphabet characters:
text_no_punctuation = re.sub(r'[^a-zA-Z\s]', '', text_no_punctuation)
# Remove HTML tags:
text_no_punctuation = re.sub(r'<.*?>', '', text_no_punctuation)
# Remove space:
text_no_punctuation = re.sub(r'\n', ' ', text_no_punctuation)

# %%
text_no_punctuation
# Out:
# ' start of the project gutenberg ebook     poirot investigates   by the same author   the mysterious affair at styles   the secret adversary   the murder on the links   the bodley head   poirot investigates   by agatha christie   london   john lane the bodley head limited   first published in great britain by   john lane company the bodley head limited    copyright   agatha christie limited   contents   i the adventure of the western star   ii the tragedy at marsdon manor   iii the adventure of the cheap flat   iv the mystery of hunters lodge   v the million dollar bond robbery   vi the adventure of the egyptian tomb   vii jewel robbery at the grand metropolitan   viii the kidnapped prime minister   ix the disappearance of mr davenheim   x the adventure of the italian nobleman   xi the case of the missing will   poirot investigates   poirot investigates   i   the adventure of the western star i was standing at the window of poirots rooms looking out idly on the street below thats queer i ejaculated suddenly beneath my breath what is mon ami asked poirot placidly from the depths of his comfortable chair deduce poirot from the following facts here is a young lady richly dressedfashionable hat magnificent furs she is coming along slowly looking up at the houses as she goes unknown to her she is being shadowed by three men and a middleaged woman they have just been joined by an errand boy who points after the girl gesticulating as he does so what drama is this being played is the girl a crook and are the shadowers detectives preparing to arrest her or are they the scoundrels and are they plotting to attack an innocent victim what does the great detective say the great detective mon ami chooses as ever the simplest course he rises to see for himself and my friend joined me at the window in a minute he gave vent to an amused chuckle as usual your facts are tinged with your incurable romanticism that is miss mary marvell the film star she is being followed by a bevy of admirers who have recognized her and en passant my dear hastings she is quite aware of the fact i laughed so all is explained but you get no marks for that poirot it was a mere matter of recognition en vrit and how many times have you seen mary marvell on the screen mon cher i thought about a dozen times perhaps and ionce yet i recognize her and you do not she looks so different i replied rather feebly ah sacr cried poirot is it that you expect her to promenade herself in the streets of london in a cowboy hat or with bare feet and a bunch of curls as an irish colleen always with you it is the nonessentials remember the case of the dancer valerie saintclair i shrugged my shoulders slightly annoyed but console yourself mon ami said poirot calming down all cannot be as hercule poirot i know it well you really have the best opinion of yourself of anyone i ever knew i cried divided between amusement and annoyance what will you when one is unique one knows it and others share that opinioneven if i mistake not miss mary marvell what without doubt she is coming here how do you make that out very simply this street it is not aristocratic mon ami in it there is no fashionable doctor no fashionable dentiststill less is there a fashionable milliner but there is a fashionable detective oui my friend it is truei am become the mode the dernier cri one says to another comment you have lost your gold pencilcase you must go to the little belgian he is too marvellous every one goes courez and they arrive in flocks mon ami with problems of the most foolish a bell rang below what did i tell you that is miss marvell as usual poirot was right after a short interval the american film star was ushered in and we rose to our feet mary marvell was undoubtedly one of the most popular actresses on the screen she had only lately arrived in england in company with her husband gregory b rolf also a film actor their marriage had taken place about a year ago in the states and this was their first visit  ...

# %% [markdown]
# Tokenize text

# %%
# Tokenize text
tokenizer = Tokenizer(lower=False)
tokenizer.fit_on_texts([text_no_punctuation])
word_index_no = tokenizer.word_index
vocabulary_size_keras = len(word_index_no) + 1

# %%
print("Vobaculary size:", vocabulary_size_keras)
# Out:
# Vobaculary size: 6264

# %% [markdown]
# Data preparation - No punctuation

# %%
# Tokenize the text into sequences
maxlen = 10  # Sequence length
step = 1  # Shift the window by 1 word

# Prepare training sequences
sequences = []

# Split the word into list
words = text_no_punctuation.split()

# Create sequences of maxlen words
for i in range(0, len(words) - maxlen, step):
    sequences.append([word_index_no[word] for word in words[i: i + maxlen]])

# Prepare X (inputs) and y (next word predictions)
x_no = np.array(sequences)
y_no = np.array([word_index_no[words[i + maxlen]] for i in range(0, len(words) - maxlen, step)])

# Print the prepared sequences and next words
print("Sequences (x):")
print(x_no)
print("\nNext words (y):")
print(y_no)
# Out:
# Sequences (x):
# [[ 351    5    1 ... 1098   41    1]
#  [   5    1 1571 ...   41    1  167]
#  [   1 1571 1572 ...    1  167 3070]
#  ...
#  [1573    5   15 ...  394    5    1]
#  [   5   15 1098 ...    5    1 1571]
#  [  15 1098   41 ...    1 1571 1572]]
#
# Next words (y):
# [ 167 3070    1 ... 1571 1572 1573]

# %%
def model_builder():

  # Model
  model = Sequential()
  model.add(Embedding(vocabulary_size_keras, 256))
  model.add(GRU(128, return_sequences=True))
  model.add(GRU(256))
  model.add(Dense(512, activation='relu'))
  model.add(Dense(256, activation='relu'))
  model.add(Dense(vocabulary_size_keras, activation='softmax'))

  # Complie
  model.compile(optimizer = RMSprop(learning_rate = 0.001, clipvalue=5.0),
                loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
# Build the model using best hyperparameters
model = model_builder()
model.fit(x_no, y_no, epochs=1, validation_split=0.1, batch_size=64)
# Out:
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 38s 47ms/step - accuracy: 0.0585 - loss: 6.9652 - val_accuracy: 0.0705 - val_loss: 6.4221
